# %% [markdown]
# ## Portfolio Exercise: Starbucks
#
# #### Background Information
#
# The dataset you will be provided in this portfolio exercise was originally used as a take-home assignment provided by Starbucks for their job candidates. The data for this exercise consists of about 120,000 data points split in a 2:1 ratio among training and test files. In the experiment simulated by the data, an advertising promotion was tested to see if it would bring more customers to purchase a specific product priced at $10. Since it costs the company 0.15 to send out each promotion, it would be best to limit that promotion only to those that are most receptive to the promotion. Each data point includes one column indicating whether or not an individual was sent a promotion for the product, and one column indicating whether or not that individual eventually purchased that product. Each individual also has seven additional features associated with them, which are provided abstractly as V1-V7.
#
# #### Optimization Strategy
#
# Your task is to use the training data to understand what patterns in V1-V7 to indicate that a promotion should be provided to a user. Specifically, your goal is to maximize the following metrics:
#
# * **Incremental Response Rate (IRR)**
#
# IRR depicts how many more customers purchased the product with the promotion, as compared to if they didn't receive the promotion. Mathematically, it's the ratio of the number of purchasers in the promotion group to the total number of customers in the purchasers group (_treatment_) minus the ratio of the number of purchasers in the non-promotional group to the total number of customers in the non-promotional group (_control_).
#
# $$ IRR = \frac{purch_{treat}}{cust_{treat}} - \frac{purch_{ctrl}}{cust_{ctrl}} $$
#
#
# * **Net Incremental Revenue (NIR)**
#
# NIR depicts how much is made (or lost) by sending out the promotion. Mathematically, this is 10 times the total number of purchasers that received the promotion minus 0.15 times the number of promotions sent out, minus 10 times the number of purchasers who were not given the promotion.
#
# $$ NIR = (10\cdot purch_{treat} - 0.15 \cdot cust_{treat}) - 10 \cdot purch_{ctrl}$$
#
# For a full description of what Starbucks provides to candidates see the [instructions available here](https://drive.google.com/open?id=18klca9Sef1Rs6q8DW4l7o349r8B70qXM).
#
# Below you can find the training data provided.  Explore the data and different optimization strategies.
#
# #### How To Test Your Strategy?
#
# When you feel like you have an optimization strategy, complete the `promotion_strategy` function to pass to the `test_results` function.
# From past data, we know there are four possible outomes:
#
# Table of actual promotion vs. predicted promotion customers:
#
# <table>
# <tr><th></th><th colspan = '2'>Actual</th></tr>
# <tr><th>Predicted</th><th>Yes</th><th>No</th></tr>
# <tr><th>Yes</th><td>I</td><td>II</td></tr>
# <tr><th>No</th><td>III</td><td>IV</td></tr>
# </table>
#
# The metrics are only being compared for the individuals we predict should obtain the promotion – that is, quadrants I and II.  Since the first set of individuals that receive the promotion (in the training set) receive it randomly, we can expect that quadrants I and II will have approximately equivalent participants.
#
# Comparing quadrant I to II then gives an idea of how well your promotion strategy will work in the future.
#
# Get started by reading in the data below.  See how each variable or combination of variables along with a promotion influences the chance of purchasing.  When you feel like you have a strategy for who should receive a promotion, test your strategy against the test dataset used in the final `test_results` function.

# %%
# load in packages
from itertools import combinations

from test_results import test_results, score
import numpy as np
import time
import pandas as pd
import scipy as sp
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import f1_score
import hyperopt
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt import space_eval
import pickle
from sklearn.metrics import f1_score
import numpy as np
import gc
import math
def f1_eval(y_pred, dtrain):
    y_true = dtrain.get_label()
    err = 1-f1_score(y_true, np.round(y_pred))
    return 'f1_err', err
import decimal
from sklearn.model_selection import KFold
def float_range(start, stop, step):
    start = decimal.Decimal(start)
    stop = decimal.Decimal(stop)
    step = decimal.Decimal(step)
    while (start < stop):
        yield float(start)
        start += step
# load in the data
train_data = pd.read_csv('./training.csv')
train_data.head()
# Out:
#    ID Promotion  purchase  V1         V2        V3  V4  V5  V6  V7
# 0   1        No         0   2  30.443518 -1.165083   1   1   3   2
# 1   3        No         0   3  32.159350 -0.645617   2   3   2   2
# 2   4        No         0   2  30.431659  0.133583   1   1   4   2
# 3   5        No         0   0  26.588914 -0.212728   2   1   4   2
# 4   8       Yes         0   3  28.044332 -0.385883   1   1   2   2

# %%
data_dir = "./data"

# %%
train_data.describe()
# Out:
#                   ID      purchase            V1            V2            V3  \
# count   84534.000000  84534.000000  84534.000000  84534.000000  84534.000000
# mean    62970.972413      0.012303      1.500662     29.973600      0.000190
# std     36418.440539      0.110234      0.868234      5.010626      1.000485
# min         1.000000      0.000000      0.000000      7.104007     -1.684550
# 25%     31467.250000      0.000000      1.000000     26.591501     -0.905350
# 50%     62827.500000      0.000000      2.000000     29.979744     -0.039572
# 75%     94438.750000      0.000000      2.000000     33.344593      0.826206
# max    126184.000000      1.000000      3.000000     50.375913      1.691984
#
#                  V4            V5            V6            V7
# count  84534.000000  84534.000000  84534.000000  84534.000000
# mean       1.679608      2.327643      2.502898      1.701694
# std        0.466630      0.841167      1.117349      0.457517
# min        1.000000      1.000000      1.000000      1.000000
# 25%        1.000000      2.000000      2.000000      1.000000
# 50%        2.000000      2.000000      3.000000      2.000000
# 75%        2.000000      3.000000      4.000000      2.000000
# max        2.000000      4.000000      4.000000      2.000000

# %%
# Cells for you to work and document as necessary - 
# definitely feel free to add more cells as you need

# %% [markdown]
# ## Exploratory analysis

# %%
train_data["Promotion"].value_counts()
# Out:
# Yes    42364
# No     42170
# Name: Promotion, dtype: int64

# %% [markdown]
# If we treat the act of giving promotion as a treatment given by the company to its customers and those that were not given promotion as the control group, then we can see that there is nearly equal number of customers that belong to both the groups.

# %% [markdown]
# ### Checking for the distribution of values of target variable of our interest

# %%
train_data["purchase"].value_counts()
# Out:
# 0    83494
# 1     1040
# Name: purchase, dtype: int64

# %% [markdown]
# It is clear from this numbers that there is a high imbalance in the number of customers who chose to purchase the product vs those who didn't. We need to take care of this while using this dataset for trainin the machine learning algorithm by using some technique like oversampling from under represented (minority) value `1` for target variable `purchase`. **SMOTE** is one useful technique that generates balanced dataset for training purpose while also introducing some variations in the input variables while oversampling the data with minority target value.

# %% [markdown]
# ## Approach 1
# ### Predicting if the customer will make the purchase only after receiving at the promotion.
#
# We are given dataset that includes customers that have been given and not given the promotion. As it costs the company 1.5$ to promote to the customer, it will try to avoid promoting it to the customers who are:
# - Not likely to purchase even after receiving the promotion
# - Are going to purchase even without receiving the promotion
#
# Company is interested in giving the promotion to the customers who are likely to make the purchase only after receiving the promotion. The job of the preditive model is to predict whether the given customer falls into this category. If yes, then our algorithm will suggest the company to give promotion to that customer, otherwise it won't suggest to give promotion to that customer.
#
# A statistical model can be trained to decide whether to give customer the promotion or not by training it with dataset where each customer is labeled as 1 in the output variable if he has been shown promotion and has purchased to product, and 0 for the rest of the scenarios. We can name this new variable as `response` as it indicates whether the customer resonded positively to our promotion.

# %%
train_data_1 = train_data.copy()

# %%
train_data_1["response"] = (train_data_1["Promotion"] == "Yes") & (train_data_1["purchase"] == 1)

# %%
features = ["V"+str(x) for x in range(1,8)] + ["Promotion"]

# %%
X = train_data_1[features]

# %%
Y = train_data_1["response"]

# %%
X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# #### Generating balanced training dataset using Synthetic Minority Over-sampling Technique (SMOTE)

# %%
sm = SMOTE(random_state=42, ratio=1.0)

# %%
X_balanced_train, Y_balanced_train = sm.fit_resample(X_train, Y_train)

# %% [markdown]
# Converting back to dataframe and series

# %%
X_balanced_train = pd.DataFrame(X_balanced_train, columns=features)

# %%
X_balanced_train.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7'], dtype='object')

# %%
Y_balanced_train = pd.Series(Y_balanced_train)

# %%
cv = GridSearchCV(estimator=XGBClassifier(), param_grid={
        "max_depth": range(5,8,1),
        "min_child_weight": [5, 10, 20, 50],
        "gamma": [0, 0.1, 0.2],
        "random_state": [42],
        "n_estimators": [1000]
        },         
        scoring="f1", cv=3)


start_time = time.time()
fit_params= {
            "eval_set": [(X_valid, Y_valid)],
            "eval_metric": f1_eval,
            "early_stopping_rounds":20,
            "verbose": 50
        }
cv.fit(X_balanced_train, Y_balanced_train, **fit_params)
elapsed_time = (time.time() - start_time) / 60
print('Elapsed computation time: {:.3f} mins'.format(elapsed_time))
# Out:
# [0]	validation_0-error:0.388419	validation_0-f1_err:0.971593
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217957	validation_0-f1_err:0.969992
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.23996	validation_0-f1_err:0.969878
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214763	validation_0-f1_err:0.969042
#
# [0]	validation_0-error:0.388419	validation_0-f1_err:0.971593
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217898	validation_0-f1_err:0.969984
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.23996	validation_0-f1_err:0.969878
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214763	validation_0-f1_err:0.969042
#
# [0]	validation_0-error:0.38836	validation_0-f1_err:0.971589
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217898	validation_0-f1_err:0.969984
#
# [0]	validation_0-error:0.38836	validation_0-f1_err:0.971589
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.239782	validation_0-f1_err:0.969856
#
# [0]	validation_0-error:0.38836	validation_0-f1_err:0.971589
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214586	validation_0-f1_err:0.969017
#
# [0]	validation_0-error:0.391613	validation_0-f1_err:0.971819
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217898	validation_0-f1_err:0.969984
#
# [0]	validation_0-error:0.391909	validation_0-f1_err:0.971839
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [12]	validation_0-error:0.180517	validation_0-f1_err:0.970738
#
# [0]	validation_0-error:0.391909	validation_0-f1_err:0.971839
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214586	validation_0-f1_err:0.969017
#
# [0]	validation_0-error:0.359437	validation_0-f1_err:0.972476
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.249009	validation_0-f1_err:0.971389
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.254037	validation_0-f1_err:0.9715
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.235701	validation_0-f1_err:0.971714
#
# [0]	validation_0-error:0.359437	validation_0-f1_err:0.972476
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.23789	validation_0-f1_err:0.971028
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.254037	validation_0-f1_err:0.9715
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.196723	validation_0-f1_err:0.971946
#
# [0]	validation_0-error:0.359378	validation_0-f1_err:0.972471
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.239191	validation_0-f1_err:0.971182
#
# [0]	validation_0-error:0.359378	validation_0-f1_err:0.972471
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.253859	validation_0-f1_err:0.97148
#
# [0]	validation_0-error:0.359378	validation_0-f1_err:0.972471
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.196605	validation_0-f1_err:0.97193
#
# [0]	validation_0-error:0.362631	validation_0-f1_err:0.972711
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.23789	validation_0-f1_err:0.971028
#
# [0]	validation_0-error:0.362927	validation_0-f1_err:0.972733
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.266753	validation_0-f1_err:0.971564
#
# [0]	validation_0-error:0.360265	validation_0-f1_err:0.972537
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.19696	validation_0-f1_err:0.971979
#
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.263796	validation_0-f1_err:0.970409
#
# [0]	validation_0-error:0.287632	validation_0-f1_err:0.972017
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [28]	validation_0-error:0.088307	validation_0-f1_err:0.97011
#
# [0]	validation_0-error:0.276631	validation_0-f1_err:0.97134
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	validation_0-error:0.276631	validation_0-f1_err:0.97134
#
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.263678	validation_0-f1_err:0.970396
#
# [0]	validation_0-error:0.288165	validation_0-f1_err:0.972067
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.174957	validation_0-f1_err:0.971748
#
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
#
# [0]	validation_0-error:0.277104	validation_0-f1_err:0.971387
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.263619	validation_0-f1_err:0.97039
#
# [0]	validation_0-error:0.287159	validation_0-f1_err:0.971972
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.251434	validation_0-f1_err:0.971657
#
# [0]	validation_0-error:0.276454	validation_0-f1_err:0.971322
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	validation_0-error:0.276454	validation_0-f1_err:0.971322
#
# [0]	validation_0-error:0.279884	validation_0-f1_err:0.971264
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.264092	validation_0-f1_err:0.970441
#
# [0]	validation_0-error:0.287869	validation_0-f1_err:0.972039
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.154315	validation_0-f1_err:0.971695
#
# [0]	validation_0-error:0.280002	validation_0-f1_err:0.971675
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214527	validation_0-f1_err:0.971605
#
# [0]	validation_0-error:0.388419	validation_0-f1_err:0.971593
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217957	validation_0-f1_err:0.969992
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.23996	validation_0-f1_err:0.969878
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214763	validation_0-f1_err:0.969042
#
# [0]	validation_0-error:0.388419	validation_0-f1_err:0.971593
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217898	validation_0-f1_err:0.969984
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.23996	validation_0-f1_err:0.969878
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214763	validation_0-f1_err:0.969042
#
# [0]	validation_0-error:0.38836	validation_0-f1_err:0.971589
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217898	validation_0-f1_err:0.969984
#
# [0]	validation_0-error:0.38836	validation_0-f1_err:0.971589
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.239782	validation_0-f1_err:0.969856
#
# [0]	validation_0-error:0.38836	validation_0-f1_err:0.971589
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214586	validation_0-f1_err:0.969017
#
# [0]	validation_0-error:0.391613	validation_0-f1_err:0.971819
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217898	validation_0-f1_err:0.969984
#
# [0]	validation_0-error:0.391909	validation_0-f1_err:0.971839
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [12]	validation_0-error:0.180517	validation_0-f1_err:0.970738
#
# [0]	validation_0-error:0.391909	validation_0-f1_err:0.971839
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214586	validation_0-f1_err:0.969017
#
# [0]	validation_0-error:0.359437	validation_0-f1_err:0.972476
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.249009	validation_0-f1_err:0.971389
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.254037	validation_0-f1_err:0.9715
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.235701	validation_0-f1_err:0.971714
#
# [0]	validation_0-error:0.359437	validation_0-f1_err:0.972476
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.23789	validation_0-f1_err:0.971028
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.254037	validation_0-f1_err:0.9715
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.196723	validation_0-f1_err:0.971946
#
# [0]	validation_0-error:0.359378	validation_0-f1_err:0.972471
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.239191	validation_0-f1_err:0.971182
#
# [0]	validation_0-error:0.359378	validation_0-f1_err:0.972471
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.253859	validation_0-f1_err:0.97148
#
# [0]	validation_0-error:0.359378	validation_0-f1_err:0.972471
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.196605	validation_0-f1_err:0.97193
#
# [0]	validation_0-error:0.362631	validation_0-f1_err:0.972711
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.23789	validation_0-f1_err:0.971028
#
# [0]	validation_0-error:0.362927	validation_0-f1_err:0.972733
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.266753	validation_0-f1_err:0.971564
#
# [0]	validation_0-error:0.360265	validation_0-f1_err:0.972537
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.19696	validation_0-f1_err:0.971979
#
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.263796	validation_0-f1_err:0.970409
#
# [0]	validation_0-error:0.287632	validation_0-f1_err:0.972017
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# [50]	validation_0-error:0.040634	validation_0-f1_err:0.982833
# Stopping. Best iteration:
# [30]	validation_0-error:0.073697	validation_0-f1_err:0.967391
#
# [0]	validation_0-error:0.276631	validation_0-f1_err:0.97134
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	validation_0-error:0.276631	validation_0-f1_err:0.97134
#
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.263678	validation_0-f1_err:0.970396
#
# [0]	validation_0-error:0.288165	validation_0-f1_err:0.972067
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.174957	validation_0-f1_err:0.971748
#
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
#
# [0]	validation_0-error:0.277104	validation_0-f1_err:0.971387
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.263619	validation_0-f1_err:0.97039
#
# [0]	validation_0-error:0.287159	validation_0-f1_err:0.971972
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.251434	validation_0-f1_err:0.971657
#
# [0]	validation_0-error:0.276454	validation_0-f1_err:0.971322
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	validation_0-error:0.276454	validation_0-f1_err:0.971322
#
# [0]	validation_0-error:0.279884	validation_0-f1_err:0.971264
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.264092	validation_0-f1_err:0.970441
#
# [0]	validation_0-error:0.287869	validation_0-f1_err:0.972039
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.154315	validation_0-f1_err:0.971695
#
# [0]	validation_0-error:0.280002	validation_0-f1_err:0.971675
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214527	validation_0-f1_err:0.971605
#
# [0]	validation_0-error:0.388419	validation_0-f1_err:0.971593
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217957	validation_0-f1_err:0.969992
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.23996	validation_0-f1_err:0.969878
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214763	validation_0-f1_err:0.969042
#
# [0]	validation_0-error:0.388419	validation_0-f1_err:0.971593
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217898	validation_0-f1_err:0.969984
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.23996	validation_0-f1_err:0.969878
#
# [0]	validation_0-error:0.388537	validation_0-f1_err:0.971602
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214763	validation_0-f1_err:0.969042
#
# [0]	validation_0-error:0.38836	validation_0-f1_err:0.971589
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217898	validation_0-f1_err:0.969984
#
# [0]	validation_0-error:0.38836	validation_0-f1_err:0.971589
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.239782	validation_0-f1_err:0.969856
#
# [0]	validation_0-error:0.38836	validation_0-f1_err:0.971589
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214586	validation_0-f1_err:0.969017
#
# [0]	validation_0-error:0.391613	validation_0-f1_err:0.971819
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	validation_0-error:0.217898	validation_0-f1_err:0.969984
#
# [0]	validation_0-error:0.391909	validation_0-f1_err:0.971839
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [12]	validation_0-error:0.180517	validation_0-f1_err:0.970738
#
# [0]	validation_0-error:0.391909	validation_0-f1_err:0.971839
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214586	validation_0-f1_err:0.969017
#
# [0]	validation_0-error:0.359437	validation_0-f1_err:0.972476
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.249009	validation_0-f1_err:0.971389
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.254037	validation_0-f1_err:0.9715
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.235701	validation_0-f1_err:0.971714
#
# [0]	validation_0-error:0.359437	validation_0-f1_err:0.972476
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.23789	validation_0-f1_err:0.971028
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.254037	validation_0-f1_err:0.9715
#
# [0]	validation_0-error:0.359555	validation_0-f1_err:0.972484
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.196723	validation_0-f1_err:0.971946
#
# [0]	validation_0-error:0.359378	validation_0-f1_err:0.972471
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.239191	validation_0-f1_err:0.971182
#
# [0]	validation_0-error:0.359378	validation_0-f1_err:0.972471
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.253859	validation_0-f1_err:0.97148
#
# [0]	validation_0-error:0.359378	validation_0-f1_err:0.972471
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.196605	validation_0-f1_err:0.97193
#
# [0]	validation_0-error:0.362631	validation_0-f1_err:0.972711
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.23789	validation_0-f1_err:0.971028
#
# [0]	validation_0-error:0.362927	validation_0-f1_err:0.972733
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.266753	validation_0-f1_err:0.971564
#
# [0]	validation_0-error:0.360265	validation_0-f1_err:0.972537
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	validation_0-error:0.19696	validation_0-f1_err:0.971979
#
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.263796	validation_0-f1_err:0.970409
#
# [0]	validation_0-error:0.287632	validation_0-f1_err:0.972017
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# [50]	validation_0-error:0.040575	validation_0-f1_err:0.971671
# Stopping. Best iteration:
# [33]	validation_0-error:0.069261	validation_0-f1_err:0.966969
#
# [0]	validation_0-error:0.276631	validation_0-f1_err:0.97134
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	validation_0-error:0.276631	validation_0-f1_err:0.97134
#
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.263678	validation_0-f1_err:0.970396
#
# [0]	validation_0-error:0.288165	validation_0-f1_err:0.972067
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.174957	validation_0-f1_err:0.971748
#
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	validation_0-error:0.277163	validation_0-f1_err:0.971393
#
# [0]	validation_0-error:0.277104	validation_0-f1_err:0.971387
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.263619	validation_0-f1_err:0.97039
#
# [0]	validation_0-error:0.287159	validation_0-f1_err:0.971972
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	validation_0-error:0.251434	validation_0-f1_err:0.971657
#
# [0]	validation_0-error:0.276454	validation_0-f1_err:0.971322
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	validation_0-error:0.276454	validation_0-f1_err:0.971322
#
# [0]	validation_0-error:0.279884	validation_0-f1_err:0.971264
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	validation_0-error:0.264092	validation_0-f1_err:0.970441
#
# [0]	validation_0-error:0.287869	validation_0-f1_err:0.972039
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	validation_0-error:0.154315	validation_0-f1_err:0.971695
#
# [0]	validation_0-error:0.280002	validation_0-f1_err:0.971675
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	validation_0-error:0.214527	validation_0-f1_err:0.971605
#
# [0]	validation_0-error:0.290235	validation_0-f1_err:0.972261
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [7]	validation_0-error:0.170521	validation_0-f1_err:0.971689
#
# Elapsed computation time: 6.720 mins

# %%
cv.best_params_
# Out:
# {'gamma': 0.2, 'max_depth': 7, 'min_child_weight': 5, 'random_state': 42}

# %%
# This will help us deciding number of estimators
xgb = XGBClassifier(n_estimators=1000)
best_params_xgb = cv.best_params_
xgb.set_params(**best_params_xgb)
xgb.fit(X=X_balanced_train, y=Y_balanced_train.values.ravel(), eval_set=[(X_valid, Y_valid)], eval_metric=f1_eval, early_stopping_rounds=10, verbose=10)
# Out:
# [0]	validation_0-error:0.290235	validation_0-f1_err:0.972261
# Multiple eval metrics have been passed: 'validation_0-f1_err' will be used for early stopping.
#
# Will train until validation_0-f1_err hasn't improved in 10 rounds.
# [10]	validation_0-error:0.14497	validation_0-f1_err:0.974553
# Stopping. Best iteration:
# [7]	validation_0-error:0.170521	validation_0-f1_err:0.971689
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.2,
#               learning_rate=0.1, max_delta_step=0, max_depth=7,
#               min_child_weight=5, missing=None, n_estimators=1000, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
optimal_n_estimators = xgb.best_ntree_limit

# %% [markdown]
# We have found out optimal max_depth and number of estimators for XGBoost algorithm for our case. Train the XGBoost on entire training dataset for using it in promotion strategy.

# %%
X_balanced, Y_balanced = sm.fit_sample(X,Y)
X_balanced = pd.DataFrame(X_balanced, columns=features)
Y_balanced = pd.Series(Y_balanced)

# %%
xgb = XGBClassifier(max_depth=best_params_xgb["max_depth"],
                    gamma=best_params_xgb["gamma"],
                    min_child_weight=best_params_xgb["min_child_weight"],
                    n_estimators=optimal_n_estimators,
                    random_state=42)
xgb.fit(X_balanced, Y_balanced)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.2,
#               learning_rate=0.1, max_delta_step=0, max_depth=7,
#               min_child_weight=5, missing=None, n_estimators=8, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
pickle.dump(xgb, open(data_dir + '/xgb_best_approach_1.pkl', 'wb'))

# %%
model = pickle.load(open(data_dir + "/xgb_best_approach_1.pkl", 'rb'))

# %%
def promotion_strategy(df):
    '''
    INPUT 
    df - a dataframe with *only* the columns V1 - V7 (same as train_data)

    OUTPUT
    promotion_df - np.array with the values
                   'Yes' or 'No' related to whether or not an 
                   individual should recieve a promotion 
                   should be the length of df.shape[0]
                
    Ex:
    INPUT: df
    
    V1	V2	  V3	V4	V5	V6	V7
    2	30	-1.1	1	1	3	2
    3	32	-0.6	2	3	2	2
    2	30	0.13	1	1	4	2
    
    OUTPUT: promotion
    
    array(['Yes', 'Yes', 'No'])
    indicating the first two users would recieve the promotion and 
    the last should not.
    '''
    
    test = df
    
    preds = model.predict(test)
    promotion = []
    for pred in preds:
        if pred:
            promotion.append('Yes')
        else:
            promotion.append('No')
    promotion = np.array(promotion)
    
    
    return promotion

# %%
test_results(promotion_strategy)
# Out:
# Nice job!  See how well your strategy worked on our test data below!
#
# Your irr with this strategy is 0.0206.
#
# Your nir with this strategy is 259.25.
# We came up with a model with an irr of 0.0188 and an nir of 189.45 on the test set.
#
#  How did you do?
# (0.020606371512773836, 259.25)

# %% [markdown]
# ## Approach 2

# %% [markdown]
# - Indicating whether a person has received promotion as input variable and training a single model to predict whether the person will make purchase or not.
# - For the purpose of deciding whether to send promotion to the person, we can first calculate the probability of person making purchase after receiving promotion and without receiving promotion by senting `promotion` input variable as 1 or 0 respectively and calculating the difference between the two probabailities. If the difference turns out to be greater than some threshold value, in that case we can send promotion to the person.
# - The value of threshold can be decided using Hyper Parameter optimization technique while using NIR formula for calcualting the return value of the objective function to be minimized i.e. the score can be -NIR.
# - Here I have used **log loss as evaluation metric** while tuning hyper parameters of XGBoost as I am more interested in calculating accurate probabilities of person giving certain response than just predicting right response.

# %%
train_data_1 = train_data.copy()

# %%
train_data_1["response"] = train_data_1["purchase"] == 1

# %%
train_data_1["response"].unique()
# Out:
# array([False,  True])

# %%
features = ["V"+str(x) for x in range(1,8)] + ["Promotion"]

# %%
# X = pd.concat([train_data_1[features],pd.get_dummies(train_data_1["Promotion"])], axis=1)

# %%
X = pd.get_dummies(train_data_1[features])

# %%
X.shape
# Out:
# (84534, 9)

# %%
features=X.columns

# %%
Y = train_data_1["response"]

# %%
X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# #### Generating balanced training dataset using Synthetic Minority Over-sampling Technique (SMOTE)

# %%
sm = SMOTE(random_state=42, ratio=1.0)

# %%
X_balanced_train, Y_balanced_train = sm.fit_resample(X_train, Y_train)

# %% [markdown]
# Converting back to dataframe and series

# %%
X_balanced_train = pd.DataFrame(X_balanced_train, columns=features)

# %%
X_balanced_train.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'Promotion_No',
#        'Promotion_Yes'],
#       dtype='object')

# %%
Y_balanced_train = pd.Series(Y_balanced_train)

# %%
cv = GridSearchCV(estimator=XGBClassifier(), param_grid={
        "max_depth": range(5,8,1),
        "min_child_weight": [5, 10, 20, 50],
        "gamma": [0, 0.1, 0.2],
        "random_state": [42],
        "n_estimators": [1000]
        },
        scoring="f1",
         cv=3)


start_time = time.time()
fit_params= {
            "eval_set": [(X_valid, Y_valid)],
            "eval_metric": "logloss",
            "early_stopping_rounds":20,
            "verbose": 50
        }
cv.fit(X_balanced_train, Y_balanced_train, **fit_params)
elapsed_time = (time.time() - start_time) / 60
print('Elapsed computation time: {:.3f} mins'.format(elapsed_time))
# Out:
# [0]	validation_0-logloss:0.655244
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.251369
# [100]	validation_0-logloss:0.171265
# [150]	validation_0-logloss:0.129084
# [200]	validation_0-logloss:0.102182
# [250]	validation_0-logloss:0.083953
# [300]	validation_0-logloss:0.075784
# [350]	validation_0-logloss:0.072174
# [400]	validation_0-logloss:0.071588
# Stopping. Best iteration:
# [381]	validation_0-logloss:0.071486
#
# [0]	validation_0-logloss:0.656642
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.262351
# [100]	validation_0-logloss:0.179657
# [150]	validation_0-logloss:0.134394
# [200]	validation_0-logloss:0.109404
# [250]	validation_0-logloss:0.092806
# [300]	validation_0-logloss:0.08443
# [350]	validation_0-logloss:0.079844
# [400]	validation_0-logloss:0.077083
# [450]	validation_0-logloss:0.075457
# [500]	validation_0-logloss:0.074352
# [550]	validation_0-logloss:0.073695
# [600]	validation_0-logloss:0.073369
# [650]	validation_0-logloss:0.072984
# [700]	validation_0-logloss:0.072769
# Stopping. Best iteration:
# [699]	validation_0-logloss:0.072764
#
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.26626
# [100]	validation_0-logloss:0.179592
# [150]	validation_0-logloss:0.136559
# [200]	validation_0-logloss:0.111674
# [250]	validation_0-logloss:0.093811
# [300]	validation_0-logloss:0.085003
# [350]	validation_0-logloss:0.079824
# [400]	validation_0-logloss:0.076982
# [450]	validation_0-logloss:0.075195
# [500]	validation_0-logloss:0.074215
# [550]	validation_0-logloss:0.073566
# [600]	validation_0-logloss:0.07315
# [650]	validation_0-logloss:0.072985
# [700]	validation_0-logloss:0.072808
# [750]	validation_0-logloss:0.072787
# Stopping. Best iteration:
# [755]	validation_0-logloss:0.072725
#
# [0]	validation_0-logloss:0.65524
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.254414
# [100]	validation_0-logloss:0.176026
# [150]	validation_0-logloss:0.133983
# [200]	validation_0-logloss:0.104389
# [250]	validation_0-logloss:0.087636
# [300]	validation_0-logloss:0.077308
# [350]	validation_0-logloss:0.073229
# [400]	validation_0-logloss:0.072063
# Stopping. Best iteration:
# [425]	validation_0-logloss:0.071758
#
# [0]	validation_0-logloss:0.65664
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.263332
# [100]	validation_0-logloss:0.177798
# [150]	validation_0-logloss:0.133985
# [200]	validation_0-logloss:0.108862
# [250]	validation_0-logloss:0.093478
# [300]	validation_0-logloss:0.084647
# [350]	validation_0-logloss:0.080004
# [400]	validation_0-logloss:0.077651
# [450]	validation_0-logloss:0.075962
# [500]	validation_0-logloss:0.075344
# [550]	validation_0-logloss:0.074518
# [600]	validation_0-logloss:0.074129
# [650]	validation_0-logloss:0.073714
# [700]	validation_0-logloss:0.073714
# [750]	validation_0-logloss:0.073568
# [800]	validation_0-logloss:0.073389
# [850]	validation_0-logloss:0.073274
# Stopping. Best iteration:
# [861]	validation_0-logloss:0.073232
#
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.266246
# [100]	validation_0-logloss:0.180395
# [150]	validation_0-logloss:0.137231
# [200]	validation_0-logloss:0.11082
# [250]	validation_0-logloss:0.093811
# [300]	validation_0-logloss:0.084893
# [350]	validation_0-logloss:0.080047
# [400]	validation_0-logloss:0.077509
# [450]	validation_0-logloss:0.075984
# [500]	validation_0-logloss:0.074956
# [550]	validation_0-logloss:0.074545
# [600]	validation_0-logloss:0.074187
# [650]	validation_0-logloss:0.073852
# [700]	validation_0-logloss:0.073638
# [750]	validation_0-logloss:0.073555
# [800]	validation_0-logloss:0.073442
# Stopping. Best iteration:
# [827]	validation_0-logloss:0.073383
#
# [0]	validation_0-logloss:0.655272
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.259716
# [100]	validation_0-logloss:0.173148
# [150]	validation_0-logloss:0.128882
# [200]	validation_0-logloss:0.10294
# [250]	validation_0-logloss:0.08705
# [300]	validation_0-logloss:0.078114
# [350]	validation_0-logloss:0.07456
# [400]	validation_0-logloss:0.073163
# [450]	validation_0-logloss:0.072649
# [500]	validation_0-logloss:0.072273
# Stopping. Best iteration:
# [498]	validation_0-logloss:0.07225
#
# [0]	validation_0-logloss:0.656667
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.26302
# [100]	validation_0-logloss:0.178076
# [150]	validation_0-logloss:0.133605
# [200]	validation_0-logloss:0.10702
# [250]	validation_0-logloss:0.09491
# [300]	validation_0-logloss:0.088066
# [350]	validation_0-logloss:0.08373
# [400]	validation_0-logloss:0.080834
# [450]	validation_0-logloss:0.07876
# [500]	validation_0-logloss:0.07768
# [550]	validation_0-logloss:0.076658
# [600]	validation_0-logloss:0.075828
# [650]	validation_0-logloss:0.075219
# [700]	validation_0-logloss:0.074737
# [750]	validation_0-logloss:0.074569
# Stopping. Best iteration:
# [766]	validation_0-logloss:0.07453
#
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.261948
# [100]	validation_0-logloss:0.17903
# [150]	validation_0-logloss:0.137197
# [200]	validation_0-logloss:0.111344
# [250]	validation_0-logloss:0.094994
# [300]	validation_0-logloss:0.08756
# [350]	validation_0-logloss:0.083601
# [400]	validation_0-logloss:0.080823
# [450]	validation_0-logloss:0.079187
# [500]	validation_0-logloss:0.077868
# [550]	validation_0-logloss:0.076904
# [600]	validation_0-logloss:0.076149
# [650]	validation_0-logloss:0.075718
# [700]	validation_0-logloss:0.075433
# [750]	validation_0-logloss:0.074908
# [800]	validation_0-logloss:0.074682
# [850]	validation_0-logloss:0.074445
# [900]	validation_0-logloss:0.074191
# Stopping. Best iteration:
# [888]	validation_0-logloss:0.074157
#
# [0]	validation_0-logloss:0.655271
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.255854
# [100]	validation_0-logloss:0.171369
# [150]	validation_0-logloss:0.126987
# [200]	validation_0-logloss:0.105857
# [250]	validation_0-logloss:0.094716
# [300]	validation_0-logloss:0.087664
# [350]	validation_0-logloss:0.082681
# [400]	validation_0-logloss:0.080031
# [450]	validation_0-logloss:0.077921
# [500]	validation_0-logloss:0.076992
# [550]	validation_0-logloss:0.07615
# [600]	validation_0-logloss:0.074562
# [650]	validation_0-logloss:0.074048
# [700]	validation_0-logloss:0.073747
# [750]	validation_0-logloss:0.073563
# [800]	validation_0-logloss:0.073392
# [850]	validation_0-logloss:0.073303
# [900]	validation_0-logloss:0.073112
# [950]	validation_0-logloss:0.072487
# Stopping. Best iteration:
# [948]	validation_0-logloss:0.072481
#
# [0]	validation_0-logloss:0.656672
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.262917
# [100]	validation_0-logloss:0.181872
# [150]	validation_0-logloss:0.138764
# [200]	validation_0-logloss:0.117246
# [250]	validation_0-logloss:0.105485
# [300]	validation_0-logloss:0.097811
# [350]	validation_0-logloss:0.092912
# [400]	validation_0-logloss:0.089191
# [450]	validation_0-logloss:0.087261
# [500]	validation_0-logloss:0.085401
# [550]	validation_0-logloss:0.083643
# [600]	validation_0-logloss:0.082293
# [650]	validation_0-logloss:0.081292
# [700]	validation_0-logloss:0.080493
# [750]	validation_0-logloss:0.079589
# [800]	validation_0-logloss:0.078848
# [850]	validation_0-logloss:0.078347
# [900]	validation_0-logloss:0.077862
# [950]	validation_0-logloss:0.077513
# [999]	validation_0-logloss:0.077172
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.264822
# [100]	validation_0-logloss:0.180662
# [150]	validation_0-logloss:0.141214
# [200]	validation_0-logloss:0.11677
# [250]	validation_0-logloss:0.107405
# [300]	validation_0-logloss:0.100293
# [350]	validation_0-logloss:0.094149
# [400]	validation_0-logloss:0.090115
# [450]	validation_0-logloss:0.087146
# [500]	validation_0-logloss:0.084967
# [550]	validation_0-logloss:0.083662
# [600]	validation_0-logloss:0.082266
# [650]	validation_0-logloss:0.081279
# [700]	validation_0-logloss:0.080479
# [750]	validation_0-logloss:0.079837
# [800]	validation_0-logloss:0.079171
# [850]	validation_0-logloss:0.078623
# [900]	validation_0-logloss:0.078195
# [950]	validation_0-logloss:0.077766
# [999]	validation_0-logloss:0.077434
# [0]	validation_0-logloss:0.651467
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.224672
# [100]	validation_0-logloss:0.143961
# [150]	validation_0-logloss:0.106476
# [200]	validation_0-logloss:0.082817
# [250]	validation_0-logloss:0.074733
# [300]	validation_0-logloss:0.072019
# Stopping. Best iteration:
# [290]	validation_0-logloss:0.071968
#
# [0]	validation_0-logloss:0.652593
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.230816
# [100]	validation_0-logloss:0.153575
# [150]	validation_0-logloss:0.114057
# [200]	validation_0-logloss:0.093356
# [250]	validation_0-logloss:0.083356
# [300]	validation_0-logloss:0.078277
# [350]	validation_0-logloss:0.075792
# [400]	validation_0-logloss:0.074115
# [450]	validation_0-logloss:0.0733
# [500]	validation_0-logloss:0.073061
# Stopping. Best iteration:
# [505]	validation_0-logloss:0.073013
#
# [0]	validation_0-logloss:0.65199
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.236013
# [100]	validation_0-logloss:0.153997
# [150]	validation_0-logloss:0.11274
# [200]	validation_0-logloss:0.091774
# [250]	validation_0-logloss:0.082903
# [300]	validation_0-logloss:0.078239
# [350]	validation_0-logloss:0.075981
# [400]	validation_0-logloss:0.074528
# [450]	validation_0-logloss:0.073894
# [500]	validation_0-logloss:0.073407
# Stopping. Best iteration:
# [526]	validation_0-logloss:0.073307
#
# [0]	validation_0-logloss:0.651464
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.218649
# [100]	validation_0-logloss:0.149136
# [150]	validation_0-logloss:0.106092
# [200]	validation_0-logloss:0.085524
# [250]	validation_0-logloss:0.076329
# [300]	validation_0-logloss:0.071962
# Stopping. Best iteration:
# [309]	validation_0-logloss:0.071861
#
# [0]	validation_0-logloss:0.652591
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.235806
# [100]	validation_0-logloss:0.154676
# [150]	validation_0-logloss:0.117237
# [200]	validation_0-logloss:0.093808
# [250]	validation_0-logloss:0.084864
# [300]	validation_0-logloss:0.079987
# [350]	validation_0-logloss:0.077
# [400]	validation_0-logloss:0.075586
# [450]	validation_0-logloss:0.074856
# [500]	validation_0-logloss:0.074369
# [550]	validation_0-logloss:0.074067
# [600]	validation_0-logloss:0.073691
# [650]	validation_0-logloss:0.073506
# Stopping. Best iteration:
# [666]	validation_0-logloss:0.073429
#
# [0]	validation_0-logloss:0.652076
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.226196
# [100]	validation_0-logloss:0.152799
# [150]	validation_0-logloss:0.112953
# [200]	validation_0-logloss:0.091571
# [250]	validation_0-logloss:0.082564
# [300]	validation_0-logloss:0.078404
# [350]	validation_0-logloss:0.075975
# [400]	validation_0-logloss:0.074622
# [450]	validation_0-logloss:0.074086
# [500]	validation_0-logloss:0.07375
# [550]	validation_0-logloss:0.073517
# Stopping. Best iteration:
# [543]	validation_0-logloss:0.073456
#
# [0]	validation_0-logloss:0.651495
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.226011
# [100]	validation_0-logloss:0.146334
# [150]	validation_0-logloss:0.106693
# [200]	validation_0-logloss:0.084061
# [250]	validation_0-logloss:0.075963
# [300]	validation_0-logloss:0.072596
# [350]	validation_0-logloss:0.071915
# [400]	validation_0-logloss:0.071349
# [450]	validation_0-logloss:0.071181
# Stopping. Best iteration:
# [447]	validation_0-logloss:0.071171
#
# [0]	validation_0-logloss:0.652618
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.237286
# [100]	validation_0-logloss:0.15242
# [150]	validation_0-logloss:0.113661
# [200]	validation_0-logloss:0.093542
# [250]	validation_0-logloss:0.086322
# [300]	validation_0-logloss:0.081759
# [350]	validation_0-logloss:0.079245
# [400]	validation_0-logloss:0.077367
# [450]	validation_0-logloss:0.076239
# [500]	validation_0-logloss:0.075333
# [550]	validation_0-logloss:0.0747
# [600]	validation_0-logloss:0.074199
# [650]	validation_0-logloss:0.073741
# [700]	validation_0-logloss:0.073573
# [750]	validation_0-logloss:0.073363
# [800]	validation_0-logloss:0.073274
# Stopping. Best iteration:
# [788]	validation_0-logloss:0.073224
#
# [0]	validation_0-logloss:0.652076
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.233492
# [100]	validation_0-logloss:0.150216
# [150]	validation_0-logloss:0.111929
# [200]	validation_0-logloss:0.093832
# [250]	validation_0-logloss:0.085317
# [300]	validation_0-logloss:0.081006
# [350]	validation_0-logloss:0.078814
# [400]	validation_0-logloss:0.077162
# [450]	validation_0-logloss:0.076243
# [500]	validation_0-logloss:0.075412
# [550]	validation_0-logloss:0.074833
# Stopping. Best iteration:
# [550]	validation_0-logloss:0.074833
#
# [0]	validation_0-logloss:0.651495
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.230027
# [100]	validation_0-logloss:0.147061
# [150]	validation_0-logloss:0.106697
# [200]	validation_0-logloss:0.09218
# [250]	validation_0-logloss:0.087279
# [300]	validation_0-logloss:0.082829
# [350]	validation_0-logloss:0.078494
# [400]	validation_0-logloss:0.076596
# [450]	validation_0-logloss:0.075452
# [500]	validation_0-logloss:0.073637
# [550]	validation_0-logloss:0.073234
# [600]	validation_0-logloss:0.073084
# Stopping. Best iteration:
# [586]	validation_0-logloss:0.072997
#
# [0]	validation_0-logloss:0.652623
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.238996
# [100]	validation_0-logloss:0.151248
# [150]	validation_0-logloss:0.116576
# [200]	validation_0-logloss:0.105127
# [250]	validation_0-logloss:0.096879
# [300]	validation_0-logloss:0.090634
# [350]	validation_0-logloss:0.086667
# [400]	validation_0-logloss:0.084631
# [450]	validation_0-logloss:0.082469
# [500]	validation_0-logloss:0.081358
# [550]	validation_0-logloss:0.080539
# [600]	validation_0-logloss:0.07962
# [650]	validation_0-logloss:0.079014
# [700]	validation_0-logloss:0.077975
# [750]	validation_0-logloss:0.077168
# [800]	validation_0-logloss:0.076879
# [850]	validation_0-logloss:0.07663
# [900]	validation_0-logloss:0.076439
# [950]	validation_0-logloss:0.076249
# [999]	validation_0-logloss:0.07602
# [0]	validation_0-logloss:0.652391
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.233012
# [100]	validation_0-logloss:0.15198
# [150]	validation_0-logloss:0.116635
# [200]	validation_0-logloss:0.103559
# [250]	validation_0-logloss:0.094562
# [300]	validation_0-logloss:0.089685
# [350]	validation_0-logloss:0.086794
# [400]	validation_0-logloss:0.084075
# [450]	validation_0-logloss:0.082341
# [500]	validation_0-logloss:0.080761
# [550]	validation_0-logloss:0.079831
# [600]	validation_0-logloss:0.079235
# [650]	validation_0-logloss:0.078628
# [700]	validation_0-logloss:0.07809
# [750]	validation_0-logloss:0.077841
# [800]	validation_0-logloss:0.077379
# [850]	validation_0-logloss:0.077033
# [900]	validation_0-logloss:0.076852
# [950]	validation_0-logloss:0.076624
# [999]	validation_0-logloss:0.076204
# [0]	validation_0-logloss:0.647659
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.206232
# [100]	validation_0-logloss:0.132195
# [150]	validation_0-logloss:0.093764
# [200]	validation_0-logloss:0.078814
# [250]	validation_0-logloss:0.072397
# Stopping. Best iteration:
# [256]	validation_0-logloss:0.07203
#
# [0]	validation_0-logloss:0.648281
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.214368
# [100]	validation_0-logloss:0.131679
# [150]	validation_0-logloss:0.098541
# [200]	validation_0-logloss:0.083424
# [250]	validation_0-logloss:0.077745
# [300]	validation_0-logloss:0.075142
# [350]	validation_0-logloss:0.074023
# [400]	validation_0-logloss:0.073594
# Stopping. Best iteration:
# [392]	validation_0-logloss:0.073504
#
# [0]	validation_0-logloss:0.646387
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.212367
# [100]	validation_0-logloss:0.139033
# [150]	validation_0-logloss:0.098865
# [200]	validation_0-logloss:0.084166
# [250]	validation_0-logloss:0.078163
# [300]	validation_0-logloss:0.075428
# [350]	validation_0-logloss:0.074214
# [400]	validation_0-logloss:0.073806
# [450]	validation_0-logloss:0.073513
# Stopping. Best iteration:
# [431]	validation_0-logloss:0.073436
#
# [0]	validation_0-logloss:0.647655
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.20815
# [100]	validation_0-logloss:0.132397
# [150]	validation_0-logloss:0.093078
# [200]	validation_0-logloss:0.076535
# [250]	validation_0-logloss:0.072488
# [300]	validation_0-logloss:0.072221
# Stopping. Best iteration:
# [288]	validation_0-logloss:0.071954
#
# [0]	validation_0-logloss:0.648279
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.218324
# [100]	validation_0-logloss:0.135213
# [150]	validation_0-logloss:0.099237
# [200]	validation_0-logloss:0.084589
# [250]	validation_0-logloss:0.079065
# [300]	validation_0-logloss:0.076845
# [350]	validation_0-logloss:0.075437
# [400]	validation_0-logloss:0.074784
# [450]	validation_0-logloss:0.07436
# [500]	validation_0-logloss:0.074127
# [550]	validation_0-logloss:0.073932
# Stopping. Best iteration:
# [556]	validation_0-logloss:0.073877
#
# [0]	validation_0-logloss:0.64647
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.215319
# [100]	validation_0-logloss:0.137485
# [150]	validation_0-logloss:0.097931
# [200]	validation_0-logloss:0.084716
# [250]	validation_0-logloss:0.078499
# [300]	validation_0-logloss:0.07595
# [350]	validation_0-logloss:0.07469
# [400]	validation_0-logloss:0.074303
# [450]	validation_0-logloss:0.074035
# [500]	validation_0-logloss:0.073946
# [550]	validation_0-logloss:0.073857
# [600]	validation_0-logloss:0.073772
# Stopping. Best iteration:
# [586]	validation_0-logloss:0.073749
#
# [0]	validation_0-logloss:0.647851
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.208014
# [100]	validation_0-logloss:0.127517
# [150]	validation_0-logloss:0.091578
# [200]	validation_0-logloss:0.077571
# [250]	validation_0-logloss:0.073579
# [300]	validation_0-logloss:0.072637
# [350]	validation_0-logloss:0.071981
# Stopping. Best iteration:
# [379]	validation_0-logloss:0.071693
#
# [0]	validation_0-logloss:0.648451
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.217
# [100]	validation_0-logloss:0.13526
# [150]	validation_0-logloss:0.103669
# [200]	validation_0-logloss:0.089498
# [250]	validation_0-logloss:0.083251
# [300]	validation_0-logloss:0.080323
# [350]	validation_0-logloss:0.078226
# [400]	validation_0-logloss:0.076813
# [450]	validation_0-logloss:0.07579
# [500]	validation_0-logloss:0.075218
# [550]	validation_0-logloss:0.074769
# [600]	validation_0-logloss:0.074672
# Stopping. Best iteration:
# [585]	validation_0-logloss:0.074641
#
# [0]	validation_0-logloss:0.646686
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.213385
# [100]	validation_0-logloss:0.132435
# [150]	validation_0-logloss:0.099618
# [200]	validation_0-logloss:0.088356
# [250]	validation_0-logloss:0.082708
# [300]	validation_0-logloss:0.079914
# [350]	validation_0-logloss:0.078296
# [400]	validation_0-logloss:0.0774
# [450]	validation_0-logloss:0.076534
# [500]	validation_0-logloss:0.075768
# [550]	validation_0-logloss:0.075339
# [600]	validation_0-logloss:0.075103
# [650]	validation_0-logloss:0.074891
# [700]	validation_0-logloss:0.074773
# Stopping. Best iteration:
# [715]	validation_0-logloss:0.07467
#
# [0]	validation_0-logloss:0.647907
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.209861
# [100]	validation_0-logloss:0.127781
# [150]	validation_0-logloss:0.100286
# [200]	validation_0-logloss:0.092435
# [250]	validation_0-logloss:0.084027
# [300]	validation_0-logloss:0.079643
# [350]	validation_0-logloss:0.077032
# [400]	validation_0-logloss:0.074985
# [450]	validation_0-logloss:0.074248
# [500]	validation_0-logloss:0.073826
# Stopping. Best iteration:
# [490]	validation_0-logloss:0.073763
#
# [0]	validation_0-logloss:0.648486
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.216566
# [100]	validation_0-logloss:0.137662
# [150]	validation_0-logloss:0.111001
# [200]	validation_0-logloss:0.097665
# [250]	validation_0-logloss:0.091376
# [300]	validation_0-logloss:0.087623
# [350]	validation_0-logloss:0.084772
# [400]	validation_0-logloss:0.082724
# [450]	validation_0-logloss:0.081252
# [500]	validation_0-logloss:0.080141
# [550]	validation_0-logloss:0.0793
# [600]	validation_0-logloss:0.078749
# [650]	validation_0-logloss:0.07819
# [700]	validation_0-logloss:0.077769
# [750]	validation_0-logloss:0.077232
# [800]	validation_0-logloss:0.076773
# [850]	validation_0-logloss:0.076412
# [900]	validation_0-logloss:0.076214
# [950]	validation_0-logloss:0.076044
# [999]	validation_0-logloss:0.075879
# [0]	validation_0-logloss:0.647361
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.215571
# [100]	validation_0-logloss:0.137798
# [150]	validation_0-logloss:0.110173
# [200]	validation_0-logloss:0.098859
# [250]	validation_0-logloss:0.093822
# [300]	validation_0-logloss:0.089852
# [350]	validation_0-logloss:0.085705
# [400]	validation_0-logloss:0.083402
# [450]	validation_0-logloss:0.081637
# [500]	validation_0-logloss:0.080652
# [550]	validation_0-logloss:0.080104
# [600]	validation_0-logloss:0.079316
# [650]	validation_0-logloss:0.078754
# [700]	validation_0-logloss:0.077958
# [750]	validation_0-logloss:0.077434
# [800]	validation_0-logloss:0.077096
# [850]	validation_0-logloss:0.076837
# [900]	validation_0-logloss:0.076751
# [950]	validation_0-logloss:0.076528
# [999]	validation_0-logloss:0.076284
# [0]	validation_0-logloss:0.655244
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.253393
# [100]	validation_0-logloss:0.169376
# [150]	validation_0-logloss:0.127903
# [200]	validation_0-logloss:0.101199
# [250]	validation_0-logloss:0.084097
# [300]	validation_0-logloss:0.076274
# [350]	validation_0-logloss:0.072732
# [400]	validation_0-logloss:0.071985
# Stopping. Best iteration:
# [405]	validation_0-logloss:0.071924
#
# [0]	validation_0-logloss:0.656642
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.26921
# [100]	validation_0-logloss:0.181091
# [150]	validation_0-logloss:0.135372
# [200]	validation_0-logloss:0.108173
# [250]	validation_0-logloss:0.093804
# [300]	validation_0-logloss:0.085169
# [350]	validation_0-logloss:0.080018
# [400]	validation_0-logloss:0.077029
# [450]	validation_0-logloss:0.075303
# [500]	validation_0-logloss:0.074024
# [550]	validation_0-logloss:0.073457
# [600]	validation_0-logloss:0.073114
# [650]	validation_0-logloss:0.072832
# [700]	validation_0-logloss:0.072674
# [750]	validation_0-logloss:0.072638
# Stopping. Best iteration:
# [730]	validation_0-logloss:0.072627
#
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.266257
# [100]	validation_0-logloss:0.179666
# [150]	validation_0-logloss:0.13602
# [200]	validation_0-logloss:0.111335
# [250]	validation_0-logloss:0.094372
# [300]	validation_0-logloss:0.085155
# [350]	validation_0-logloss:0.08017
# [400]	validation_0-logloss:0.077314
# [450]	validation_0-logloss:0.075553
# [500]	validation_0-logloss:0.074694
# [550]	validation_0-logloss:0.073998
# [600]	validation_0-logloss:0.073684
# [650]	validation_0-logloss:0.073438
# [700]	validation_0-logloss:0.073291
# Stopping. Best iteration:
# [689]	validation_0-logloss:0.073258
#
# [0]	validation_0-logloss:0.65524
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.251631
# [100]	validation_0-logloss:0.171154
# [150]	validation_0-logloss:0.129647
# [200]	validation_0-logloss:0.100985
# [250]	validation_0-logloss:0.084679
# [300]	validation_0-logloss:0.076694
# [350]	validation_0-logloss:0.073409
# [400]	validation_0-logloss:0.072083
# [450]	validation_0-logloss:0.071536
# Stopping. Best iteration:
# [454]	validation_0-logloss:0.071505
#
# [0]	validation_0-logloss:0.65664
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.263328
# [100]	validation_0-logloss:0.17839
# [150]	validation_0-logloss:0.136469
# [200]	validation_0-logloss:0.110414
# [250]	validation_0-logloss:0.093473
# [300]	validation_0-logloss:0.084855
# [350]	validation_0-logloss:0.080108
# [400]	validation_0-logloss:0.077694
# [450]	validation_0-logloss:0.075992
# [500]	validation_0-logloss:0.075071
# [550]	validation_0-logloss:0.074292
# [600]	validation_0-logloss:0.073907
# [650]	validation_0-logloss:0.073608
# [700]	validation_0-logloss:0.073385
# [750]	validation_0-logloss:0.073324
# Stopping. Best iteration:
# [764]	validation_0-logloss:0.073229
#
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.26625
# [100]	validation_0-logloss:0.181644
# [150]	validation_0-logloss:0.13548
# [200]	validation_0-logloss:0.108537
# [250]	validation_0-logloss:0.093725
# [300]	validation_0-logloss:0.084899
# [350]	validation_0-logloss:0.080237
# [400]	validation_0-logloss:0.077672
# [450]	validation_0-logloss:0.07621
# [500]	validation_0-logloss:0.075337
# [550]	validation_0-logloss:0.07474
# [600]	validation_0-logloss:0.074344
# [650]	validation_0-logloss:0.074088
# [700]	validation_0-logloss:0.073755
# [750]	validation_0-logloss:0.073517
# [800]	validation_0-logloss:0.073357
# Stopping. Best iteration:
# [807]	validation_0-logloss:0.073327
#
# [0]	validation_0-logloss:0.655272
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.259717
# [100]	validation_0-logloss:0.172547
# [150]	validation_0-logloss:0.129042
# [200]	validation_0-logloss:0.102383
# [250]	validation_0-logloss:0.087858
# [300]	validation_0-logloss:0.079337
# [350]	validation_0-logloss:0.075083
# [400]	validation_0-logloss:0.073481
# [450]	validation_0-logloss:0.072511
# [500]	validation_0-logloss:0.072151
# [550]	validation_0-logloss:0.071964
# Stopping. Best iteration:
# [568]	validation_0-logloss:0.071911
#
# [0]	validation_0-logloss:0.656667
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.263021
# [100]	validation_0-logloss:0.180337
# [150]	validation_0-logloss:0.132725
# [200]	validation_0-logloss:0.108216
# [250]	validation_0-logloss:0.09527
# [300]	validation_0-logloss:0.088848
# [350]	validation_0-logloss:0.083346
# [400]	validation_0-logloss:0.080877
# [450]	validation_0-logloss:0.079177
# [500]	validation_0-logloss:0.077614
# [550]	validation_0-logloss:0.07672
# [600]	validation_0-logloss:0.075963
# [650]	validation_0-logloss:0.075407
# [700]	validation_0-logloss:0.074971
# [750]	validation_0-logloss:0.074619
# [800]	validation_0-logloss:0.074507
# Stopping. Best iteration:
# [790]	validation_0-logloss:0.074438
#
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.261951
# [100]	validation_0-logloss:0.179179
# [150]	validation_0-logloss:0.134828
# [200]	validation_0-logloss:0.109805
# [250]	validation_0-logloss:0.094426
# [300]	validation_0-logloss:0.087403
# [350]	validation_0-logloss:0.083147
# [400]	validation_0-logloss:0.080296
# [450]	validation_0-logloss:0.078841
# [500]	validation_0-logloss:0.07737
# [550]	validation_0-logloss:0.076377
# [600]	validation_0-logloss:0.07564
# [650]	validation_0-logloss:0.075229
# [700]	validation_0-logloss:0.074997
# [750]	validation_0-logloss:0.074814
# Stopping. Best iteration:
# [737]	validation_0-logloss:0.074742
#
# [0]	validation_0-logloss:0.655271
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.255855
# [100]	validation_0-logloss:0.172302
# [150]	validation_0-logloss:0.128464
# [200]	validation_0-logloss:0.106973
# [250]	validation_0-logloss:0.097268
# [300]	validation_0-logloss:0.08967
# [350]	validation_0-logloss:0.085022
# [400]	validation_0-logloss:0.08134
# [450]	validation_0-logloss:0.078575
# [500]	validation_0-logloss:0.076695
# [550]	validation_0-logloss:0.075368
# [600]	validation_0-logloss:0.074564
# [650]	validation_0-logloss:0.074018
# [700]	validation_0-logloss:0.073623
# [750]	validation_0-logloss:0.073033
# [800]	validation_0-logloss:0.072523
# Stopping. Best iteration:
# [782]	validation_0-logloss:0.072452
#
# [0]	validation_0-logloss:0.656672
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.262919
# [100]	validation_0-logloss:0.181871
# [150]	validation_0-logloss:0.137041
# [200]	validation_0-logloss:0.115919
# [250]	validation_0-logloss:0.10574
# [300]	validation_0-logloss:0.099584
# [350]	validation_0-logloss:0.093758
# [400]	validation_0-logloss:0.089767
# [450]	validation_0-logloss:0.086537
# [500]	validation_0-logloss:0.084608
# [550]	validation_0-logloss:0.083081
# [600]	validation_0-logloss:0.081965
# [650]	validation_0-logloss:0.081112
# [700]	validation_0-logloss:0.080175
# [750]	validation_0-logloss:0.079498
# [800]	validation_0-logloss:0.078821
# [850]	validation_0-logloss:0.078261
# [900]	validation_0-logloss:0.077712
# [950]	validation_0-logloss:0.077385
# [999]	validation_0-logloss:0.07711
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.264819
# [100]	validation_0-logloss:0.180985
# [150]	validation_0-logloss:0.140559
# [200]	validation_0-logloss:0.119267
# [250]	validation_0-logloss:0.107751
# [300]	validation_0-logloss:0.100059
# [350]	validation_0-logloss:0.093661
# [400]	validation_0-logloss:0.08959
# [450]	validation_0-logloss:0.086566
# [500]	validation_0-logloss:0.084591
# [550]	validation_0-logloss:0.083332
# [600]	validation_0-logloss:0.08221
# [650]	validation_0-logloss:0.081297
# [700]	validation_0-logloss:0.080576
# [750]	validation_0-logloss:0.079607
# [800]	validation_0-logloss:0.078913
# [850]	validation_0-logloss:0.078347
# [900]	validation_0-logloss:0.077979
# [950]	validation_0-logloss:0.077579
# [999]	validation_0-logloss:0.077257
# [0]	validation_0-logloss:0.651467
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.22467
# [100]	validation_0-logloss:0.145383
# [150]	validation_0-logloss:0.109017
# [200]	validation_0-logloss:0.080783
# [250]	validation_0-logloss:0.074323
# [300]	validation_0-logloss:0.071347
# Stopping. Best iteration:
# [295]	validation_0-logloss:0.071257
#
# [0]	validation_0-logloss:0.652593
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.232403
# [100]	validation_0-logloss:0.153501
# [150]	validation_0-logloss:0.114414
# [200]	validation_0-logloss:0.091734
# [250]	validation_0-logloss:0.082857
# [300]	validation_0-logloss:0.078415
# [350]	validation_0-logloss:0.075849
# [400]	validation_0-logloss:0.074712
# [450]	validation_0-logloss:0.073992
# [500]	validation_0-logloss:0.073638
# [550]	validation_0-logloss:0.073309
# Stopping. Best iteration:
# [532]	validation_0-logloss:0.073286
#
# [0]	validation_0-logloss:0.65199
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.23709
# [100]	validation_0-logloss:0.154672
# [150]	validation_0-logloss:0.112067
# [200]	validation_0-logloss:0.092511
# [250]	validation_0-logloss:0.081921
# [300]	validation_0-logloss:0.07736
# [350]	validation_0-logloss:0.074954
# [400]	validation_0-logloss:0.074085
# [450]	validation_0-logloss:0.073349
# [500]	validation_0-logloss:0.073062
# [550]	validation_0-logloss:0.072815
# [600]	validation_0-logloss:0.072599
# Stopping. Best iteration:
# [605]	validation_0-logloss:0.072576
#
# [0]	validation_0-logloss:0.651464
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.223941
# [100]	validation_0-logloss:0.145371
# [150]	validation_0-logloss:0.107417
# [200]	validation_0-logloss:0.084449
# [250]	validation_0-logloss:0.07475
# [300]	validation_0-logloss:0.072436
# [350]	validation_0-logloss:0.072021
# Stopping. Best iteration:
# [365]	validation_0-logloss:0.071784
#
# [0]	validation_0-logloss:0.652591
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.235822
# [100]	validation_0-logloss:0.154694
# [150]	validation_0-logloss:0.113059
# [200]	validation_0-logloss:0.093036
# [250]	validation_0-logloss:0.083841
# [300]	validation_0-logloss:0.078799
# [350]	validation_0-logloss:0.076214
# [400]	validation_0-logloss:0.075007
# [450]	validation_0-logloss:0.074305
# [500]	validation_0-logloss:0.073746
# [550]	validation_0-logloss:0.073531
# [600]	validation_0-logloss:0.073404
# Stopping. Best iteration:
# [582]	validation_0-logloss:0.073358
#
# [0]	validation_0-logloss:0.652076
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.226246
# [100]	validation_0-logloss:0.153162
# [150]	validation_0-logloss:0.111222
# [200]	validation_0-logloss:0.092738
# [250]	validation_0-logloss:0.082928
# [300]	validation_0-logloss:0.078734
# [350]	validation_0-logloss:0.076391
# [400]	validation_0-logloss:0.074842
# [450]	validation_0-logloss:0.074092
# [500]	validation_0-logloss:0.073744
# [550]	validation_0-logloss:0.073563
# [600]	validation_0-logloss:0.07326
# Stopping. Best iteration:
# [606]	validation_0-logloss:0.073251
#
# [0]	validation_0-logloss:0.651495
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.226877
# [100]	validation_0-logloss:0.148587
# [150]	validation_0-logloss:0.104609
# [200]	validation_0-logloss:0.08444
# [250]	validation_0-logloss:0.076021
# [300]	validation_0-logloss:0.073504
# [350]	validation_0-logloss:0.07236
# [400]	validation_0-logloss:0.071708
# [450]	validation_0-logloss:0.071724
# Stopping. Best iteration:
# [438]	validation_0-logloss:0.071597
#
# [0]	validation_0-logloss:0.652618
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.237279
# [100]	validation_0-logloss:0.155128
# [150]	validation_0-logloss:0.112315
# [200]	validation_0-logloss:0.093322
# [250]	validation_0-logloss:0.085286
# [300]	validation_0-logloss:0.08163
# [350]	validation_0-logloss:0.079237
# [400]	validation_0-logloss:0.077474
# [450]	validation_0-logloss:0.076144
# [500]	validation_0-logloss:0.075309
# [550]	validation_0-logloss:0.074865
# [600]	validation_0-logloss:0.074538
# [650]	validation_0-logloss:0.074274
# Stopping. Best iteration:
# [656]	validation_0-logloss:0.074191
#
# [0]	validation_0-logloss:0.652076
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.233492
# [100]	validation_0-logloss:0.15182
# [150]	validation_0-logloss:0.110373
# [200]	validation_0-logloss:0.093213
# [250]	validation_0-logloss:0.086394
# [300]	validation_0-logloss:0.082032
# [350]	validation_0-logloss:0.079408
# [400]	validation_0-logloss:0.077843
# [450]	validation_0-logloss:0.076681
# [500]	validation_0-logloss:0.07582
# [550]	validation_0-logloss:0.075144
# [600]	validation_0-logloss:0.074809
# Stopping. Best iteration:
# [614]	validation_0-logloss:0.074729
#
# [0]	validation_0-logloss:0.651495
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.232764
# [100]	validation_0-logloss:0.148011
# [150]	validation_0-logloss:0.109842
# [200]	validation_0-logloss:0.093852
# [250]	validation_0-logloss:0.086562
# [300]	validation_0-logloss:0.082002
# [350]	validation_0-logloss:0.078406
# [400]	validation_0-logloss:0.075814
# [450]	validation_0-logloss:0.074228
# [500]	validation_0-logloss:0.073707
# [550]	validation_0-logloss:0.073172
# [600]	validation_0-logloss:0.073011
# [650]	validation_0-logloss:0.072742
# [700]	validation_0-logloss:0.072589
# Stopping. Best iteration:
# [694]	validation_0-logloss:0.072567
#
# [0]	validation_0-logloss:0.652623
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.238995
# [100]	validation_0-logloss:0.151176
# [150]	validation_0-logloss:0.118943
# [200]	validation_0-logloss:0.103899
# [250]	validation_0-logloss:0.096019
# [300]	validation_0-logloss:0.09096
# [350]	validation_0-logloss:0.087588
# [400]	validation_0-logloss:0.084806
# [450]	validation_0-logloss:0.083186
# [500]	validation_0-logloss:0.081617
# [550]	validation_0-logloss:0.080522
# [600]	validation_0-logloss:0.079396
# [650]	validation_0-logloss:0.078876
# [700]	validation_0-logloss:0.078097
# [750]	validation_0-logloss:0.077756
# [800]	validation_0-logloss:0.077292
# [850]	validation_0-logloss:0.076876
# [900]	validation_0-logloss:0.076644
# [950]	validation_0-logloss:0.076393
# Stopping. Best iteration:
# [941]	validation_0-logloss:0.076362
#
# [0]	validation_0-logloss:0.652391
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.233822
# [100]	validation_0-logloss:0.152341
# [150]	validation_0-logloss:0.118568
# [200]	validation_0-logloss:0.10372
# [250]	validation_0-logloss:0.097853
# [300]	validation_0-logloss:0.091751
# [350]	validation_0-logloss:0.087389
# [400]	validation_0-logloss:0.084433
# [450]	validation_0-logloss:0.082752
# [500]	validation_0-logloss:0.081538
# [550]	validation_0-logloss:0.080634
# [600]	validation_0-logloss:0.079628
# [650]	validation_0-logloss:0.078846
# [700]	validation_0-logloss:0.078279
# [750]	validation_0-logloss:0.078055
# [800]	validation_0-logloss:0.077407
# [850]	validation_0-logloss:0.076992
# [900]	validation_0-logloss:0.076553
# [950]	validation_0-logloss:0.076317
# [999]	validation_0-logloss:0.076118
# [0]	validation_0-logloss:0.647659
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.202414
# [100]	validation_0-logloss:0.133179
# [150]	validation_0-logloss:0.09154
# [200]	validation_0-logloss:0.076797
# [250]	validation_0-logloss:0.072528
# Stopping. Best iteration:
# [266]	validation_0-logloss:0.072341
#
# [0]	validation_0-logloss:0.648281
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.217531
# [100]	validation_0-logloss:0.131577
# [150]	validation_0-logloss:0.096894
# [200]	validation_0-logloss:0.081933
# [250]	validation_0-logloss:0.076914
# [300]	validation_0-logloss:0.074955
# [350]	validation_0-logloss:0.073934
# [400]	validation_0-logloss:0.073497
# Stopping. Best iteration:
# [423]	validation_0-logloss:0.073335
#
# [0]	validation_0-logloss:0.646387
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.21571
# [100]	validation_0-logloss:0.137106
# [150]	validation_0-logloss:0.099441
# [200]	validation_0-logloss:0.084767
# [250]	validation_0-logloss:0.078225
# [300]	validation_0-logloss:0.075768
# [350]	validation_0-logloss:0.0745
# [400]	validation_0-logloss:0.074059
# [450]	validation_0-logloss:0.073694
# Stopping. Best iteration:
# [473]	validation_0-logloss:0.073602
#
# [0]	validation_0-logloss:0.647655
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.207422
# [100]	validation_0-logloss:0.135686
# [150]	validation_0-logloss:0.093197
# [200]	validation_0-logloss:0.076575
# [250]	validation_0-logloss:0.072509
# [300]	validation_0-logloss:0.072227
# Stopping. Best iteration:
# [281]	validation_0-logloss:0.072099
#
# [0]	validation_0-logloss:0.648279
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.21925
# [100]	validation_0-logloss:0.134475
# [150]	validation_0-logloss:0.098423
# [200]	validation_0-logloss:0.08385
# [250]	validation_0-logloss:0.078285
# [300]	validation_0-logloss:0.075607
# [350]	validation_0-logloss:0.074777
# [400]	validation_0-logloss:0.074156
# [450]	validation_0-logloss:0.073762
# [500]	validation_0-logloss:0.073397
# Stopping. Best iteration:
# [491]	validation_0-logloss:0.07338
#
# [0]	validation_0-logloss:0.64647
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.214876
# [100]	validation_0-logloss:0.1345
# [150]	validation_0-logloss:0.098463
# [200]	validation_0-logloss:0.084383
# [250]	validation_0-logloss:0.078679
# [300]	validation_0-logloss:0.07593
# [350]	validation_0-logloss:0.075021
# [400]	validation_0-logloss:0.074508
# [450]	validation_0-logloss:0.074135
# Stopping. Best iteration:
# [473]	validation_0-logloss:0.074024
#
# [0]	validation_0-logloss:0.647851
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.208244
# [100]	validation_0-logloss:0.131266
# [150]	validation_0-logloss:0.092777
# [200]	validation_0-logloss:0.079212
# [250]	validation_0-logloss:0.074072
# [300]	validation_0-logloss:0.073265
# [350]	validation_0-logloss:0.072667
# [400]	validation_0-logloss:0.072528
# Stopping. Best iteration:
# [383]	validation_0-logloss:0.07233
#
# [0]	validation_0-logloss:0.648451
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.212295
# [100]	validation_0-logloss:0.132456
# [150]	validation_0-logloss:0.100289
# [200]	validation_0-logloss:0.087725
# [250]	validation_0-logloss:0.082246
# [300]	validation_0-logloss:0.079801
# [350]	validation_0-logloss:0.077893
# [400]	validation_0-logloss:0.076744
# [450]	validation_0-logloss:0.075819
# [500]	validation_0-logloss:0.075288
# [550]	validation_0-logloss:0.074926
# [600]	validation_0-logloss:0.074538
# [650]	validation_0-logloss:0.074283
# [700]	validation_0-logloss:0.074103
# Stopping. Best iteration:
# [717]	validation_0-logloss:0.074063
# [0]	validation_0-logloss:0.646686
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.213386
# [100]	validation_0-logloss:0.13192
# [150]	validation_0-logloss:0.099025
# [200]	validation_0-logloss:0.08775
# [250]	validation_0-logloss:0.082114
# [300]	validation_0-logloss:0.07959
# [350]	validation_0-logloss:0.077865
# [400]	validation_0-logloss:0.076573
# [450]	validation_0-logloss:0.07572
# [500]	validation_0-logloss:0.075447
# [550]	validation_0-logloss:0.075072
# [600]	validation_0-logloss:0.074766
# [650]	validation_0-logloss:0.074411
# Stopping. Best iteration:
# [663]	validation_0-logloss:0.074407
#
# [0]	validation_0-logloss:0.647907
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.20986
# [100]	validation_0-logloss:0.129292
# [150]	validation_0-logloss:0.10303
# [200]	validation_0-logloss:0.092937
# [250]	validation_0-logloss:0.082743
# [300]	validation_0-logloss:0.079527
# [350]	validation_0-logloss:0.077209
# [400]	validation_0-logloss:0.075151
# [450]	validation_0-logloss:0.07447
# [500]	validation_0-logloss:0.0738
# [550]	validation_0-logloss:0.073371
# [600]	validation_0-logloss:0.07317
# [650]	validation_0-logloss:0.072908
# Stopping. Best iteration:
# [673]	validation_0-logloss:0.072856
#
# [0]	validation_0-logloss:0.648486
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.222825
# [100]	validation_0-logloss:0.138042
# [150]	validation_0-logloss:0.111559
# [200]	validation_0-logloss:0.100279
# [250]	validation_0-logloss:0.092126
# [300]	validation_0-logloss:0.087005
# [350]	validation_0-logloss:0.084613
# [400]	validation_0-logloss:0.08302
# [450]	validation_0-logloss:0.081493
# [500]	validation_0-logloss:0.080395
# [550]	validation_0-logloss:0.07929
# [600]	validation_0-logloss:0.078569
# [650]	validation_0-logloss:0.077907
# [700]	validation_0-logloss:0.077614
# [750]	validation_0-logloss:0.077145
# [800]	validation_0-logloss:0.076761
# [850]	validation_0-logloss:0.076536
# [900]	validation_0-logloss:0.076169
# [950]	validation_0-logloss:0.075941
# [999]	validation_0-logloss:0.075762
# [0]	validation_0-logloss:0.647361
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.214741
# [100]	validation_0-logloss:0.138806
# [150]	validation_0-logloss:0.110752
# [200]	validation_0-logloss:0.098427
# [250]	validation_0-logloss:0.091545
# [300]	validation_0-logloss:0.087762
# [350]	validation_0-logloss:0.085177
# [400]	validation_0-logloss:0.083059
# [450]	validation_0-logloss:0.081225
# [500]	validation_0-logloss:0.080185
# [550]	validation_0-logloss:0.079474
# [600]	validation_0-logloss:0.07882
# [650]	validation_0-logloss:0.078175
# [700]	validation_0-logloss:0.077396
# [750]	validation_0-logloss:0.077054
# [800]	validation_0-logloss:0.076773
# [850]	validation_0-logloss:0.076469
# [900]	validation_0-logloss:0.076199
# [950]	validation_0-logloss:0.076079
# [999]	validation_0-logloss:0.075878
# [0]	validation_0-logloss:0.655244
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.253165
# [100]	validation_0-logloss:0.171921
# [150]	validation_0-logloss:0.129586
# [200]	validation_0-logloss:0.1013
# [250]	validation_0-logloss:0.083631
# [300]	validation_0-logloss:0.075329
# [350]	validation_0-logloss:0.07185
# [400]	validation_0-logloss:0.071371
# Stopping. Best iteration:
# [386]	validation_0-logloss:0.071284
#
# [0]	validation_0-logloss:0.656642
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.269204
# [100]	validation_0-logloss:0.179535
# [150]	validation_0-logloss:0.135224
# [200]	validation_0-logloss:0.108382
# [250]	validation_0-logloss:0.094042
# [300]	validation_0-logloss:0.08482
# [350]	validation_0-logloss:0.080064
# [400]	validation_0-logloss:0.077335
# [450]	validation_0-logloss:0.075647
# [500]	validation_0-logloss:0.07449
# [550]	validation_0-logloss:0.073902
# [600]	validation_0-logloss:0.073425
# [650]	validation_0-logloss:0.073139
# [700]	validation_0-logloss:0.072965
# [750]	validation_0-logloss:0.072883
# [800]	validation_0-logloss:0.072791
# Stopping. Best iteration:
# [786]	validation_0-logloss:0.072743
#
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.266584
# [100]	validation_0-logloss:0.180459
# [150]	validation_0-logloss:0.136234
# [200]	validation_0-logloss:0.110125
# [250]	validation_0-logloss:0.093002
# [300]	validation_0-logloss:0.08396
# [350]	validation_0-logloss:0.079412
# [400]	validation_0-logloss:0.07704
# [450]	validation_0-logloss:0.075276
# [500]	validation_0-logloss:0.074353
# [550]	validation_0-logloss:0.073786
# [600]	validation_0-logloss:0.073305
# [650]	validation_0-logloss:0.073083
# [700]	validation_0-logloss:0.073061
# Stopping. Best iteration:
# [680]	validation_0-logloss:0.073005
#
# [0]	validation_0-logloss:0.65524
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.254417
# [100]	validation_0-logloss:0.175962
# [150]	validation_0-logloss:0.132299
# [200]	validation_0-logloss:0.104331
# [250]	validation_0-logloss:0.087056
# [300]	validation_0-logloss:0.076914
# [350]	validation_0-logloss:0.072688
# [400]	validation_0-logloss:0.071803
# Stopping. Best iteration:
# [397]	validation_0-logloss:0.071772
#
# [0]	validation_0-logloss:0.65664
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.263324
# [100]	validation_0-logloss:0.178814
# [150]	validation_0-logloss:0.135223
# [200]	validation_0-logloss:0.109459
# [250]	validation_0-logloss:0.093141
# [300]	validation_0-logloss:0.084316
# [350]	validation_0-logloss:0.08005
# [400]	validation_0-logloss:0.077811
# [450]	validation_0-logloss:0.07613
# [500]	validation_0-logloss:0.075012
# [550]	validation_0-logloss:0.07432
# [600]	validation_0-logloss:0.073943
# [650]	validation_0-logloss:0.073667
# [700]	validation_0-logloss:0.073457
# [750]	validation_0-logloss:0.073209
# [800]	validation_0-logloss:0.073027
# [850]	validation_0-logloss:0.072909
# [900]	validation_0-logloss:0.072783
# [950]	validation_0-logloss:0.072686
# Stopping. Best iteration:
# [965]	validation_0-logloss:0.072637
#
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.266252
# [100]	validation_0-logloss:0.179976
# [150]	validation_0-logloss:0.135953
# [200]	validation_0-logloss:0.111695
# [250]	validation_0-logloss:0.094223
# [300]	validation_0-logloss:0.085176
# [350]	validation_0-logloss:0.080633
# [400]	validation_0-logloss:0.077988
# [450]	validation_0-logloss:0.076256
# [500]	validation_0-logloss:0.075189
# [550]	validation_0-logloss:0.074534
# [600]	validation_0-logloss:0.074134
# [650]	validation_0-logloss:0.074017
# [700]	validation_0-logloss:0.073778
# [750]	validation_0-logloss:0.073508
# [800]	validation_0-logloss:0.073298
# Stopping. Best iteration:
# [801]	validation_0-logloss:0.073293
#
# [0]	validation_0-logloss:0.655272
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.259717
# ...
# [800]	validation_0-logloss:0.072886
# [850]	validation_0-logloss:0.072767
# Stopping. Best iteration:
# [848]	validation_0-logloss:0.072732
#
# [0]	validation_0-logloss:0.656672
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.262943
# [100]	validation_0-logloss:0.182144
# [150]	validation_0-logloss:0.138526
# [200]	validation_0-logloss:0.116212
# [250]	validation_0-logloss:0.105047
# [300]	validation_0-logloss:0.097633
# [350]	validation_0-logloss:0.092809
# [400]	validation_0-logloss:0.089332
# [450]	validation_0-logloss:0.08706
# [500]	validation_0-logloss:0.08489
# [550]	validation_0-logloss:0.082828
# [600]	validation_0-logloss:0.08171
# [650]	validation_0-logloss:0.080827
# [700]	validation_0-logloss:0.080075
# [750]	validation_0-logloss:0.079537
# [800]	validation_0-logloss:0.078923
# [850]	validation_0-logloss:0.078438
# [900]	validation_0-logloss:0.078039
# [950]	validation_0-logloss:0.07756
# [999]	validation_0-logloss:0.077391
# [0]	validation_0-logloss:0.656049
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.263246
# [100]	validation_0-logloss:0.178141
# [150]	validation_0-logloss:0.140949
# [200]	validation_0-logloss:0.119433
# [250]	validation_0-logloss:0.106736
# [300]	validation_0-logloss:0.098962
# [350]	validation_0-logloss:0.093918
# [400]	validation_0-logloss:0.090458
# [450]	validation_0-logloss:0.087954
# [500]	validation_0-logloss:0.085406
# [550]	validation_0-logloss:0.083831
# [600]	validation_0-logloss:0.082765
# [650]	validation_0-logloss:0.081772
# [700]	validation_0-logloss:0.08014
# [750]	validation_0-logloss:0.079437
# [800]	validation_0-logloss:0.078765
# [850]	validation_0-logloss:0.078334
# [900]	validation_0-logloss:0.077809
# [950]	validation_0-logloss:0.077355
# [999]	validation_0-logloss:0.076919
# [0]	validation_0-logloss:0.651467
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.221348
# [100]	validation_0-logloss:0.146061
# [150]	validation_0-logloss:0.106359
# [200]	validation_0-logloss:0.08322
# [250]	validation_0-logloss:0.075084
# [300]	validation_0-logloss:0.071965
# Stopping. Best iteration:
# [308]	validation_0-logloss:0.07162
#
# [0]	validation_0-logloss:0.652593
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.233905
# [100]	validation_0-logloss:0.152938
# [150]	validation_0-logloss:0.112781
# [200]	validation_0-logloss:0.091316
# [250]	validation_0-logloss:0.082552
# [300]	validation_0-logloss:0.077391
# [350]	validation_0-logloss:0.075287
# [400]	validation_0-logloss:0.07433
# [450]	validation_0-logloss:0.073413
# Stopping. Best iteration:
# [458]	validation_0-logloss:0.073322
#
# [0]	validation_0-logloss:0.65199
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.231501
# [100]	validation_0-logloss:0.157599
# [150]	validation_0-logloss:0.115045
# [200]	validation_0-logloss:0.092939
# [250]	validation_0-logloss:0.083795
# [300]	validation_0-logloss:0.078464
# [350]	validation_0-logloss:0.075762
# [400]	validation_0-logloss:0.074211
# [450]	validation_0-logloss:0.073702
# Stopping. Best iteration:
# [472]	validation_0-logloss:0.073429
#
# [0]	validation_0-logloss:0.651464
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.223685
# [100]	validation_0-logloss:0.146311
# [150]	validation_0-logloss:0.108458
# [200]	validation_0-logloss:0.084244
# [250]	validation_0-logloss:0.074765
# [300]	validation_0-logloss:0.07212
# Stopping. Best iteration:
# [314]	validation_0-logloss:0.071993
#
# [0]	validation_0-logloss:0.652591
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.235729
# [100]	validation_0-logloss:0.154752
# [150]	validation_0-logloss:0.114637
# [200]	validation_0-logloss:0.093224
# [250]	validation_0-logloss:0.084005
# [300]	validation_0-logloss:0.078981
# [350]	validation_0-logloss:0.076218
# [400]	validation_0-logloss:0.074875
# [450]	validation_0-logloss:0.074321
# [500]	validation_0-logloss:0.074143
# [550]	validation_0-logloss:0.073772
# [600]	validation_0-logloss:0.073494
# [650]	validation_0-logloss:0.073423
# Stopping. Best iteration:
# [646]	validation_0-logloss:0.073392
#
# [0]	validation_0-logloss:0.652076
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.226236
# [100]	validation_0-logloss:0.154101
# [150]	validation_0-logloss:0.113151
# [200]	validation_0-logloss:0.091541
# [250]	validation_0-logloss:0.082476
# [300]	validation_0-logloss:0.078124
# [350]	validation_0-logloss:0.07559
# [400]	validation_0-logloss:0.074296
# [450]	validation_0-logloss:0.073868
# [500]	validation_0-logloss:0.073523
# [550]	validation_0-logloss:0.0733
# Stopping. Best iteration:
# [555]	validation_0-logloss:0.07326
#
# [0]	validation_0-logloss:0.651495
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.225689
# [100]	validation_0-logloss:0.147365
# [150]	validation_0-logloss:0.104493
# [200]	validation_0-logloss:0.082712
# [250]	validation_0-logloss:0.076803
# [300]	validation_0-logloss:0.072279
# [350]	validation_0-logloss:0.07169
# [400]	validation_0-logloss:0.071402
# Stopping. Best iteration:
# [405]	validation_0-logloss:0.071369
#
# [0]	validation_0-logloss:0.652618
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.237277
# [100]	validation_0-logloss:0.156375
# [150]	validation_0-logloss:0.113183
# [200]	validation_0-logloss:0.094144
# [250]	validation_0-logloss:0.086546
# [300]	validation_0-logloss:0.081555
# [350]	validation_0-logloss:0.079012
# [400]	validation_0-logloss:0.077477
# [450]	validation_0-logloss:0.076352
# [500]	validation_0-logloss:0.075585
# [550]	validation_0-logloss:0.074795
# [600]	validation_0-logloss:0.074371
# [650]	validation_0-logloss:0.074107
# [700]	validation_0-logloss:0.073888
# [750]	validation_0-logloss:0.073711
# Stopping. Best iteration:
# [771]	validation_0-logloss:0.073608
#
# [0]	validation_0-logloss:0.652076
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.23437
# [100]	validation_0-logloss:0.151894
# [150]	validation_0-logloss:0.11001
# [200]	validation_0-logloss:0.093841
# [250]	validation_0-logloss:0.085644
# [300]	validation_0-logloss:0.081438
# [350]	validation_0-logloss:0.079141
# [400]	validation_0-logloss:0.077678
# [450]	validation_0-logloss:0.076258
# [500]	validation_0-logloss:0.075468
# [550]	validation_0-logloss:0.075044
# [600]	validation_0-logloss:0.074625
# [650]	validation_0-logloss:0.074267
# Stopping. Best iteration:
# [645]	validation_0-logloss:0.074236
#
# [0]	validation_0-logloss:0.651495
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.232759
# [100]	validation_0-logloss:0.145973
# [150]	validation_0-logloss:0.108529
# [200]	validation_0-logloss:0.093947
# [250]	validation_0-logloss:0.087517
# [300]	validation_0-logloss:0.082365
# [350]	validation_0-logloss:0.079643
# [400]	validation_0-logloss:0.077127
# [450]	validation_0-logloss:0.075582
# [500]	validation_0-logloss:0.074172
# [550]	validation_0-logloss:0.073816
# [600]	validation_0-logloss:0.07336
# [650]	validation_0-logloss:0.072527
# Stopping. Best iteration:
# [668]	validation_0-logloss:0.072469
#
# [0]	validation_0-logloss:0.652623
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.238998
# [100]	validation_0-logloss:0.147953
# [150]	validation_0-logloss:0.114771
# [200]	validation_0-logloss:0.102148
# [250]	validation_0-logloss:0.095525
# [300]	validation_0-logloss:0.091171
# [350]	validation_0-logloss:0.086765
# [400]	validation_0-logloss:0.083995
# [450]	validation_0-logloss:0.082159
# [500]	validation_0-logloss:0.080727
# [550]	validation_0-logloss:0.079872
# [600]	validation_0-logloss:0.07898
# [650]	validation_0-logloss:0.078245
# [700]	validation_0-logloss:0.077857
# [750]	validation_0-logloss:0.077456
# [800]	validation_0-logloss:0.076969
# [850]	validation_0-logloss:0.076426
# [900]	validation_0-logloss:0.076258
# [950]	validation_0-logloss:0.07607
# [999]	validation_0-logloss:0.075921
# [0]	validation_0-logloss:0.652391
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.233039
# [100]	validation_0-logloss:0.153284
# [150]	validation_0-logloss:0.12085
# [200]	validation_0-logloss:0.103506
# [250]	validation_0-logloss:0.096609
# [300]	validation_0-logloss:0.09031
# [350]	validation_0-logloss:0.086423
# [400]	validation_0-logloss:0.084442
# [450]	validation_0-logloss:0.082432
# [500]	validation_0-logloss:0.081052
# [550]	validation_0-logloss:0.080132
# [600]	validation_0-logloss:0.079317
# [650]	validation_0-logloss:0.078511
# [700]	validation_0-logloss:0.077903
# [750]	validation_0-logloss:0.077574
# [800]	validation_0-logloss:0.077226
# [850]	validation_0-logloss:0.076942
# [900]	validation_0-logloss:0.076619
# [950]	validation_0-logloss:0.076151
# [999]	validation_0-logloss:0.075889
# [0]	validation_0-logloss:0.647659
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.202427
# [100]	validation_0-logloss:0.13407
# [150]	validation_0-logloss:0.094759
# [200]	validation_0-logloss:0.077663
# [250]	validation_0-logloss:0.072666
# Stopping. Best iteration:
# [271]	validation_0-logloss:0.072427
#
# [0]	validation_0-logloss:0.648281
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.219481
# [100]	validation_0-logloss:0.1316
# [150]	validation_0-logloss:0.097442
# [200]	validation_0-logloss:0.081817
# [250]	validation_0-logloss:0.076735
# [300]	validation_0-logloss:0.074709
# [350]	validation_0-logloss:0.073763
# [400]	validation_0-logloss:0.073484
# Stopping. Best iteration:
# [384]	validation_0-logloss:0.073434
#
# [0]	validation_0-logloss:0.646387
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.214674
# [100]	validation_0-logloss:0.134586
# [150]	validation_0-logloss:0.09867
# [200]	validation_0-logloss:0.083869
# [250]	validation_0-logloss:0.077799
# [300]	validation_0-logloss:0.075487
# [350]	validation_0-logloss:0.074244
# [400]	validation_0-logloss:0.073662
# [450]	validation_0-logloss:0.073335
# Stopping. Best iteration:
# [448]	validation_0-logloss:0.073331
#
# [0]	validation_0-logloss:0.647655
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.207217
# [100]	validation_0-logloss:0.136028
# [150]	validation_0-logloss:0.093575
# [200]	validation_0-logloss:0.077047
# [250]	validation_0-logloss:0.072423
# [300]	validation_0-logloss:0.072468
# Stopping. Best iteration:
# [280]	validation_0-logloss:0.072283
#
# [0]	validation_0-logloss:0.648279
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.219273
# [100]	validation_0-logloss:0.136374
# [150]	validation_0-logloss:0.099847
# [200]	validation_0-logloss:0.08483
# [250]	validation_0-logloss:0.078855
# [300]	validation_0-logloss:0.076208
# [350]	validation_0-logloss:0.075132
# [400]	validation_0-logloss:0.074606
# [450]	validation_0-logloss:0.074161
# Stopping. Best iteration:
# [453]	validation_0-logloss:0.074126
#
# [0]	validation_0-logloss:0.64647
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.214872
# [100]	validation_0-logloss:0.133215
# [150]	validation_0-logloss:0.0989
# [200]	validation_0-logloss:0.083794
# [250]	validation_0-logloss:0.0787
# [300]	validation_0-logloss:0.075993
# [350]	validation_0-logloss:0.074826
# [400]	validation_0-logloss:0.07426
# [450]	validation_0-logloss:0.073996
# [500]	validation_0-logloss:0.073717
# Stopping. Best iteration:
# [499]	validation_0-logloss:0.073705
#
# [0]	validation_0-logloss:0.647851
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.208247
# [100]	validation_0-logloss:0.13203
# [150]	validation_0-logloss:0.090644
# [200]	validation_0-logloss:0.077375
# [250]	validation_0-logloss:0.073591
# [300]	validation_0-logloss:0.072716
# [350]	validation_0-logloss:0.072376
# Stopping. Best iteration:
# [376]	validation_0-logloss:0.071972
#
# [0]	validation_0-logloss:0.648451
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.216189
# [100]	validation_0-logloss:0.133949
# [150]	validation_0-logloss:0.100108
# [200]	validation_0-logloss:0.088726
# [250]	validation_0-logloss:0.082961
# [300]	validation_0-logloss:0.079894
# [350]	validation_0-logloss:0.077984
# [400]	validation_0-logloss:0.076721
# [450]	validation_0-logloss:0.076093
# [500]	validation_0-logloss:0.075439
# [550]	validation_0-logloss:0.075003
# [600]	validation_0-logloss:0.07469
# Stopping. Best iteration:
# [623]	validation_0-logloss:0.074595
#
# [0]	validation_0-logloss:0.646686
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.215699
# [100]	validation_0-logloss:0.133654
# [150]	validation_0-logloss:0.100636
# [200]	validation_0-logloss:0.087645
# [250]	validation_0-logloss:0.08213
# [300]	validation_0-logloss:0.079136
# [350]	validation_0-logloss:0.077574
# [400]	validation_0-logloss:0.076386
# [450]	validation_0-logloss:0.075736
# [500]	validation_0-logloss:0.075419
# [550]	validation_0-logloss:0.074988
# [600]	validation_0-logloss:0.074621
# [650]	validation_0-logloss:0.074417
# Stopping. Best iteration:
# [648]	validation_0-logloss:0.074387
#
# [0]	validation_0-logloss:0.647907
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.209861
# [100]	validation_0-logloss:0.130052
# [150]	validation_0-logloss:0.103215
# [200]	validation_0-logloss:0.091856
# [250]	validation_0-logloss:0.083125
# [300]	validation_0-logloss:0.079536
# [350]	validation_0-logloss:0.077736
# [400]	validation_0-logloss:0.075175
# [450]	validation_0-logloss:0.073824
# [500]	validation_0-logloss:0.073326
# [550]	validation_0-logloss:0.073027
# [600]	validation_0-logloss:0.072923
# [650]	validation_0-logloss:0.072726
# Stopping. Best iteration:
# [674]	validation_0-logloss:0.072654
#
# [0]	validation_0-logloss:0.648486
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.222826
# [100]	validation_0-logloss:0.138896
# [150]	validation_0-logloss:0.108659
# [200]	validation_0-logloss:0.096865
# [250]	validation_0-logloss:0.091454
# [300]	validation_0-logloss:0.087779
# [350]	validation_0-logloss:0.085559
# [400]	validation_0-logloss:0.083813
# [450]	validation_0-logloss:0.082144
# [500]	validation_0-logloss:0.080897
# [550]	validation_0-logloss:0.07941
# [600]	validation_0-logloss:0.078735
# [650]	validation_0-logloss:0.078142
# [700]	validation_0-logloss:0.077625
# [750]	validation_0-logloss:0.077243
# [800]	validation_0-logloss:0.076756
# [850]	validation_0-logloss:0.07653
# [900]	validation_0-logloss:0.076147
# [950]	validation_0-logloss:0.076019
# [999]	validation_0-logloss:0.075907
# [0]	validation_0-logloss:0.647361
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.217282
# [100]	validation_0-logloss:0.139308
# [150]	validation_0-logloss:0.112464
# [200]	validation_0-logloss:0.100184
# [250]	validation_0-logloss:0.092705
# [300]	validation_0-logloss:0.087875
# [350]	validation_0-logloss:0.084687
# [400]	validation_0-logloss:0.082869
# [450]	validation_0-logloss:0.081647
# [500]	validation_0-logloss:0.080395
# [550]	validation_0-logloss:0.079556
# [600]	validation_0-logloss:0.078654
# [650]	validation_0-logloss:0.077841
# [700]	validation_0-logloss:0.077285
# [750]	validation_0-logloss:0.077012
# [800]	validation_0-logloss:0.07677
# [850]	validation_0-logloss:0.076408
# [900]	validation_0-logloss:0.07622
# [950]	validation_0-logloss:0.076069
# [999]	validation_0-logloss:0.075875
# [0]	validation_0-logloss:0.651736
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [50]	validation_0-logloss:0.230457
# [100]	validation_0-logloss:0.152161
# [150]	validation_0-logloss:0.110356
# [200]	validation_0-logloss:0.088276
# [250]	validation_0-logloss:0.079036
# [300]	validation_0-logloss:0.074299
# [350]	validation_0-logloss:0.072308
# [400]	validation_0-logloss:0.071203
# [450]	validation_0-logloss:0.070651
# [500]	validation_0-logloss:0.070361
# [550]	validation_0-logloss:0.070151
# [600]	validation_0-logloss:0.069974
# [650]	validation_0-logloss:0.06996
# Stopping. Best iteration:
# [634]	validation_0-logloss:0.069892
#
# Elapsed computation time: 147.557 mins

# %%
cv.best_params_
# Out:
# {'gamma': 0.1,
#  'max_depth': 6,
#  'min_child_weight': 10,
#  'n_estimators': 1000,
#  'random_state': 42}

# %%
# This will help us deciding number of estimators
xgb = XGBClassifier(n_estimators=1000)
best_params_xgb = cv.best_params_
xgb.set_params(**best_params_xgb)
xgb.fit(X=X_balanced_train, y=Y_balanced_train.values.ravel(), eval_set=[(X_valid, Y_valid)], eval_metric="logloss", early_stopping_rounds=10, verbose=10)
# Out:
# [0]	validation_0-logloss:0.651736
# Will train until validation_0-logloss hasn't improved in 10 rounds.
# [10]	validation_0-logloss:0.467548
# [20]	validation_0-logloss:0.361545
# [30]	validation_0-logloss:0.298454
# [40]	validation_0-logloss:0.25701
# [50]	validation_0-logloss:0.230457
# [60]	validation_0-logloss:0.211893
# [70]	validation_0-logloss:0.19325
# [80]	validation_0-logloss:0.179203
# [90]	validation_0-logloss:0.163888
# [100]	validation_0-logloss:0.152161
# [110]	validation_0-logloss:0.139522
# [120]	validation_0-logloss:0.132642
# [130]	validation_0-logloss:0.124634
# [140]	validation_0-logloss:0.117031
# [150]	validation_0-logloss:0.110356
# [160]	validation_0-logloss:0.104467
# [170]	validation_0-logloss:0.100311
# [180]	validation_0-logloss:0.094953
# [190]	validation_0-logloss:0.090794
# [200]	validation_0-logloss:0.088276
# [210]	validation_0-logloss:0.085795
# [220]	validation_0-logloss:0.084368
# [230]	validation_0-logloss:0.082699
# [240]	validation_0-logloss:0.080333
# [250]	validation_0-logloss:0.079036
# [260]	validation_0-logloss:0.077853
# [270]	validation_0-logloss:0.076522
# [280]	validation_0-logloss:0.075776
# [290]	validation_0-logloss:0.075155
# [300]	validation_0-logloss:0.074299
# [310]	validation_0-logloss:0.073751
# [320]	validation_0-logloss:0.073337
# [330]	validation_0-logloss:0.073036
# [340]	validation_0-logloss:0.072558
# [350]	validation_0-logloss:0.072308
# [360]	validation_0-logloss:0.072077
# [370]	validation_0-logloss:0.071781
# [380]	validation_0-logloss:0.07163
# [390]	validation_0-logloss:0.071283
# [400]	validation_0-logloss:0.071203
# [410]	validation_0-logloss:0.071086
# [420]	validation_0-logloss:0.07099
# [430]	validation_0-logloss:0.070879
# [440]	validation_0-logloss:0.070729
# [450]	validation_0-logloss:0.070651
# [460]	validation_0-logloss:0.070625
# [470]	validation_0-logloss:0.070538
# [480]	validation_0-logloss:0.070495
# [490]	validation_0-logloss:0.070458
# [500]	validation_0-logloss:0.070361
# [510]	validation_0-logloss:0.070321
# [520]	validation_0-logloss:0.070278
# [530]	validation_0-logloss:0.070228
# Stopping. Best iteration:
# [527]	validation_0-logloss:0.070218
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.1,
#               learning_rate=0.1, max_delta_step=0, max_depth=6,
#               min_child_weight=10, missing=None, n_estimators=1000, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
optimal_n_estimators = xgb.best_ntree_limit

# %% [markdown]
# We have found out optimal max_depth and number of estimators for XGBoost algorithm for our case. Train the XGBoost on entire training dataset for using it in promotion strategy.

# %%
X_balanced, Y_balanced = sm.fit_sample(X,Y)
X_balanced = pd.DataFrame(X_balanced, columns=features)
Y_balanced = pd.Series(Y_balanced)

# %%
xgb = XGBClassifier(max_depth=best_params_xgb["max_depth"],
                    gamma=best_params_xgb["gamma"],
                    min_child_weight=best_params_xgb["min_child_weight"],
                    n_estimators=optimal_n_estimators,
                    random_state=42)
xgb.fit(X_balanced, Y_balanced)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.1,
#               learning_rate=0.1, max_delta_step=0, max_depth=6,
#               min_child_weight=10, missing=None, n_estimators=528, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
pickle.dump(xgb, open(data_dir + '/xgb_best_approach_2.pkl', 'wb'))

# %%
model = pickle.load(open(data_dir + "/xgb_best_approach_2.pkl", 'rb'))

# %% [markdown]
# We define `diff` as difference in the probabilities of person purchasing the product with and without receiving promotion. We have to choose the threshold value and if the `diff` is higher than that threshold value than we can choose to show promotion to that person. To decide the value of threshold that maximizes the NIR for given prediction model, I evaluate the thresholds in range from 0 to 0.1 by calculating the mean of NIR on 10 folds of the validation dataset and choose threshold value with maximum NIR.

# %%
def evaluate(X, Y, diff_threshold, after_promotion_purchase_prob_threshold):
    def score(df, promo_pred_col = 'Promotion'):
        n_treat       = df.loc[df[promo_pred_col] == 'Yes',:].shape[0]
        n_control     = df.loc[df[promo_pred_col] == 'No',:].shape[0]
        n_treat_purch = df.loc[df[promo_pred_col] == 'Yes', 'purchase'].sum()
        n_ctrl_purch  = df.loc[df[promo_pred_col] == 'No', 'purchase'].sum()
        nir = 10 * n_treat_purch - 0.15 * n_treat - 10 * n_ctrl_purch
        return nir
    
    nir_scores = []
    kf = KFold(n_splits=10, random_state=42)
    for train_index, test_index in kf.split(X):
        X_train, X_valid = X.loc[train_index], X.loc[test_index]
        Y_train, Y_valid = Y.loc[train_index], Y.loc[test_index]
        
        # As we have already trained the hyper parameters for XGBoost, we need not train it again here
        # we can use the trained model, to calculate score for given threshold value
        model = pickle.load(open(data_dir + "/xgb_best_approach_2.pkl", 'rb'))
        
        X_valid_with_promo = X_valid.copy()
        # predict probability of purchase with promotion
        X_valid_with_promo["Promotion_Yes"] = 1
        X_valid_with_promo["Promotion_No"] = 0
        probs_with_promotion = model.predict_proba(X_valid_with_promo)[:, 1]

        # predict probability of purchase without promotion
        X_valid_with_promo["Promotion_Yes"] = 0
        X_valid_with_promo["Promotion_No"] = 1

        probs_without_promotion = model.predict_proba(X_valid_with_promo)[:, 1]

        # calculate the difference as diff
        diff = probs_with_promotion - probs_without_promotion

        # if diff is above threshold choose to promote else don't
        promos = (probs_with_promotion > after_promotion_purchase_prob_threshold) & (diff > diff_threshold)
        val_data = X_valid.copy()
        val_data["Promotion"] = "No"
        val_data.loc[val_data["Promotion_Yes"] == 1, "Promotion"] = "Yes"
        val_data["purchase"] = Y_valid.copy()
        score_df = val_data.iloc[np.where(promos)]
        nir = score(score_df)
        nir_scores.append(nir)
    return np.asscalar(np.mean(nir_scores))

# %%
(X_valid.index == Y_valid.index).all()
# Out:
# True

# %%
evaluated_point_scores = {}

def objective_threshold(params):
    if (str(params) in evaluated_point_scores):
        return evaluated_point_scores[str(params)]
    else:
        print(params)
        diff_threshold = params["diff_threshold"]
        after_promotion_purchase_prob_threshold = params["after_promotion_purchase_prob_threshold"]
        nir_score = evaluate(X=X_valid, Y=Y_valid, 
                             diff_threshold=diff_threshold, 
                             after_promotion_purchase_prob_threshold=after_promotion_purchase_prob_threshold)
        print("nir: " + str(nir_score))        
        evaluated_point_scores[str(params)] = -nir_score
        return -nir_score

param_space = {
    "diff_threshold": hp.choice("diff_threshold", list(float_range("0.02", "0.04", "0.001"))),
    "after_promotion_purchase_prob_threshold": hp.choice("after_promotion_purchase_prob_threshold", list(float_range("0.0", "1.0", "0.1")))
}

start_time = time.time()
best_params_threshold = space_eval(
    param_space, 
    fmin(objective_threshold, 
         param_space, 
         algo=hyperopt.tpe.suggest,
         max_evals=200))
print(best_params_threshold)
elapsed_time = (time.time() - start_time) / 60
print('Elapsed computation time: {:.3f} mins'.format(elapsed_time))
best_diff_threshold = best_params_threshold["diff_threshold"]
best_after_promotion_purchase_prob_threshold = best_params_threshold["after_promotion_purchase_prob_threshold"]
# Out:
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.036}
#   0%|          | 0/200 [00:00<?, ?it/s, best loss: ?]
# /Users/atharva/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   del sys.path[0]
#
# /Users/atharva/.pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.02}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.025}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.021}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.022}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.027}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.034}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.2, 'diff_threshold': 0.021}
# nir: 2.91
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.039}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.033}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.023}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.039}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.036}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.029}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.4, 'diff_threshold': 0.037}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.028}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.02}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.3, 'diff_threshold': 0.034}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.033}
# nir: 12.934999999999999
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.031}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.03}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.024}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.2, 'diff_threshold': 0.024}
# nir: 2.91
# {'after_promotion_purchase_prob_threshold': 0.3, 'diff_threshold': 0.03}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.038}
# nir: 12.715
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.032}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.4, 'diff_threshold': 0.035}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.026}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.024}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.025}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.029}
# nir: 13.409999999999997
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.027}
# nir: 13.945000000000002
# {'after_promotion_purchase_prob_threshold': 0.2, 'diff_threshold': 0.027}
# nir: 2.91
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.022}
# nir: 12.805000000000001
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.027}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.023}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.027}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.4, 'diff_threshold': 0.021}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.3, 'diff_threshold': 0.037}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.028}
# nir: 14.184999999999999
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.026}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.2, 'diff_threshold': 0.028}
# nir: 2.91
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.028}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.028}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.3, 'diff_threshold': 0.02}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.4, 'diff_threshold': 0.028}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.034}
# nir: 13.219999999999999
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.038}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.032}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.036}
# nir: 13.415000000000001
# {'after_promotion_purchase_prob_threshold': 0.2, 'diff_threshold': 0.035}
# nir: 2.91
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.025}
# nir: 12.51
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.031}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.023}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.03}
# nir: 13.560000000000002
# {'after_promotion_purchase_prob_threshold': 0.3, 'diff_threshold': 0.028}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.033}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.02}
# nir: 13.084999999999999
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.021}
# nir: 12.430000000000001
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.034}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.2, 'diff_threshold': 0.038}
# nir: 2.91
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.026}
# nir: 13.825
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.024}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.032}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.031}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.028}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.03}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.2, 'diff_threshold': 0.023}
# nir: 2.91
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.021}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.028}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.037}
# nir: 14.535
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.037}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.037}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.039}
# nir: 12.85
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.026}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.024}
# nir: 12.315000000000001
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.032}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.035}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.029}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.022}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.4, 'diff_threshold': 0.031}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.2, 'diff_threshold': 0.02}
# nir: 2.91
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.021}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.026}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.4, 'diff_threshold': 0.038}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.3, 'diff_threshold': 0.024}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.036}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.035}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.032}
# nir: 12.830000000000002
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.029}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.031}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.022}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.03}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.021}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.037}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.2, 'diff_threshold': 0.037}
# nir: 2.91
# {'after_promotion_purchase_prob_threshold': 0.7, 'diff_threshold': 0.037}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.033}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.4, 'diff_threshold': 0.02}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.3, 'diff_threshold': 0.026}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.034}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.024}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.4, 'diff_threshold': 0.022}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.023}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.033}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.039}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.6, 'diff_threshold': 0.034}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.9, 'diff_threshold': 0.036}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.3, 'diff_threshold': 0.038}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.4, 'diff_threshold': 0.032}
# nir: 1.97
# {'after_promotion_purchase_prob_threshold': 0.1, 'diff_threshold': 0.035}
# nir: 13.01
# {'after_promotion_purchase_prob_threshold': 0.8, 'diff_threshold': 0.027}
# nir: 0.0
# {'after_promotion_purchase_prob_threshold': 0.5, 'diff_threshold': 0.022}
# nir: 0.985
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.031}
# nir: 12.725
# 100%|██████████| 200/200 [01:07<00:00,  2.94it/s, best loss: -14.535]
# {'after_promotion_purchase_prob_threshold': 0.0, 'diff_threshold': 0.037}
# Elapsed computation time: 1.124 mins

# %%
def promotion_strategy(df):
    '''
    INPUT 
    df - a dataframe with *only* the columns V1 - V7 (same as train_data)

    OUTPUT
    promotion_df - np.array with the values
                   'Yes' or 'No' related to whether or not an 
                   individual should recieve a promotion 
                   should be the length of df.shape[0]
                
    Ex:
    INPUT: df
    
    V1	V2	  V3	V4	V5	V6	V7
    2	30	-1.1	1	1	3	2
    3	32	-0.6	2	3	2	2
    2	30	0.13	1	1	4	2
    
    OUTPUT: promotion
    
    array(['Yes', 'Yes', 'No'])
    indicating the first two users would recieve the promotion and 
    the last should not.
    '''
    X = df.copy()
    # predict probability of purchase with promotion

    X["Promotion_No"] = 0
    X["Promotion_Yes"] = 1
    probs_with_promotion = model.predict_proba(X)[:, 1]


    # predict probability of purchase without promotion
    
    X["Promotion_No"] = 1
    X["Promotion_Yes"] = 0
    probs_without_promotion = model.predict_proba(X)[:, 1]

    # calculate the difference as diff
    diff = probs_with_promotion - probs_without_promotion        

    should_promote = pd.DataFrame() 
    should_promote["promo"] = (probs_with_promotion > best_after_promotion_purchase_prob_threshold) & (diff > best_diff_threshold)
    
    should_promote.loc[diff >= best_threshold, "promo"] = "Yes"
    should_promote.loc[diff < best_threshold, "promo"] = "No"    
    return should_promote["promo"].to_numpy(dtype="str")

# %%
test_results(promotion_strategy)
# Out:
# Nice job!  See how well your strategy worked on our test data below!
#
# Your irr with this strategy is 0.0179.
#
# Your nir with this strategy is 105.75.
# We came up with a model with an irr of 0.0188 and an nir of 189.45 on the test set.
#
#  How did you do?
# (0.017909013159424635, 105.75)

# %% [markdown]
# # Approach 3

# %% [markdown]
# Here I am trying the two models approach that is commonly recommended on literature related to uplift measurement. In this approach, we create one model for people who have received the promotion and another model for those who haven't received it. Each model predicts whether the person would purchase the product. The difference between the probability predicted by first model and second model is to be considered for deciding wether to promote to to that person or not. Caveat here is that the error of prediction can get doubled as we are using two separate models. Also the scale of the probabilities may not be the same.
